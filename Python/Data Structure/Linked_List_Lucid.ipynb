# %%
# All my files about linked lists 
# Mainly form lucidprogramming youtube

# %%
# linked List
# Basic Insertions to the Linked List

# Node contains the data and a pointer to the next data in the Linked List
class Node:
    def __init__(self,data):
        self.data = data
        self.next = None

# Linked list has a head object and we continue adding nodes to the list
class LinkedList(object):
    def __init__(self):
        self.head = None
        
#     Add a node to the end of the list
    def append(self, data):
        new_node = Node(data)
        
        if self.head is None:
            self.head = new_node
            return 
        last_node = self.head
        while last_node.next: # same as (while last_node is None:)
            last_node = last_node.next
        last_node.next = new_node
    
#     Print the contents of the linked list
    def print_list(self):
        cur_node = self.head
        while cur_node: # same as (while cur_node is None:)
            print(cur_node.data)
            cur_node = cur_node.next

#     Add a node to the begining of the list    
    def prepend(self, data):
        new_node = Node(data)
        
        new_node.next = self.head
        self.head = new_node
    
    
#     Insert a node at a specific point in the list provided the element exists
    def insert_after(self, prev_node, data):
        if not prev_node:
            print("Node not found in the list")
            return
        new_node = Node(data)        
        new_node.next = prev_node.next
        prev_node.next = new_node
        
        
example_list = LinkedList()
example_list.append("A")
example_list.append("B")
example_list.append("C")
example_list.append("D")

# example_list.prepend("F")

example_list.insert_after(example_list.head.next,"E")

example_list.print_list()

# %%
# Delete Nodes

# linked List
# Basic Insertions to the Linked List

# Node contains the data and a pointer to the next data in the Linked List
class Node:
    def __init__(self,data):
        self.data = data
        self.next = None

# Linked list has a head object and we continue adding nodes to the list
class LinkedList(object):
    def __init__(self):
        self.head = None
        
#     Add a node to the end of the list
    def append(self, data):
        new_node = Node(data)
        
        if self.head is None:
            self.head = new_node
            return 
        last_node = self.head
        while last_node.next:
            last_node = last_node.next
        last_node.next = new_node
    
#     Print the contents of the linked list
    def print_list(self):
        cur_node = self.head
        while cur_node: # same as (while cur_node is None:)
            print(cur_node.data)
            cur_node = cur_node.next
            
    def delete_head(self):
        
        self.head.next = self.head
        

        
        
list_example = LinkedList()
A = ['A','B','C','D']
for i in A:
    list_example.append(i)


# list_example.delete_node(list_example.head)

list_example.print_list()

list_example.delete_head()

list_example.print_list()
