# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

# %%
# Simple graph

# Data
x = [-1,4,6]
y = [5,-9,7]

# Plot
plt.plot(x,y)

# Plot names
plt.title("Test")
plt.xlabel("x-axis")
plt.ylabel("y-axis")

# Display plot
plt.show()

# %%
# Multiple lines

# Data
x = [3,5,8]
y = [1,6,9]
z = [2,7,8]

# Plot
plt.plot(x,y)
plt.plot(x,z)
# plt.plot(y,z)

# Plot legends
plt.title("Test")
plt.xlabel("x-axis")
plt.ylabel("y z-axis")
plt.legend(['x','y','z'])

# Display plot
plt.show()
