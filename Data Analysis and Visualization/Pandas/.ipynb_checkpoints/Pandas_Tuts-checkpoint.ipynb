# %% [markdown]
# # Pandas Tutorial

# %%
# Importing the required libraries

import pandas as pd

# %% [markdown]
# ### Read a csv file and print

# %%
# Reading a csv file using pandas and assigning it to a variable/DataFrame

data_f = pd.read_csv("survey_results_public.csv")

# Schema results
schema_f = pd.read_csv("survey_results_schema.csv")

# Print the DataFrame
data_f
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 0               1                     I am a developer by profession      Yes
# 1               2                     I am a developer by profession       No
# 2               3                        I code primarily as a hobby      Yes
# 3               4                     I am a developer by profession      Yes
# 4               5  I used to be a developer by profession, but no...      Yes
# ...           ...                                                ...      ...
# 64456       64858                                                NaN      Yes
# 64457       64867                                                NaN      Yes
# 64458       64898                                                NaN      Yes
# 64459       64925                                                NaN      Yes
# 64460       65112                                                NaN      Yes
#
#         Age Age1stCode CompFreq  CompTotal  ConvertedComp             Country  \
# 0       NaN         13  Monthly        NaN            NaN             Germany
# 1       NaN         19      NaN        NaN            NaN      United Kingdom
# 2       NaN         15      NaN        NaN            NaN  Russian Federation
# 3      25.0         18      NaN        NaN            NaN             Albania
# 4      31.0         16      NaN        NaN            NaN       United States
# ...     ...        ...      ...        ...            ...                 ...
# 64456   NaN         16      NaN        NaN            NaN       United States
# 64457   NaN        NaN      NaN        NaN            NaN             Morocco
# 64458   NaN        NaN      NaN        NaN            NaN            Viet Nam
# 64459   NaN        NaN      NaN        NaN            NaN              Poland
# 64460   NaN        NaN      NaN        NaN            NaN               Spain
#
#          CurrencyDesc  ...                  SurveyEase           SurveyLength  \
# 0       European Euro  ...  Neither easy nor difficult  Appropriate in length
# 1      Pound sterling  ...                         NaN                    NaN
# 2                 NaN  ...  Neither easy nor difficult  Appropriate in length
# 3        Albanian lek  ...                         NaN                    NaN
# 4                 NaN  ...                        Easy              Too short
# ...               ...  ...                         ...                    ...
# 64456             NaN  ...                         NaN                    NaN
# 64457             NaN  ...                         NaN                    NaN
# 64458             NaN  ...                         NaN                    NaN
# 64459             NaN  ...                         NaN                    NaN
# 64460             NaN  ...                         NaN                    NaN
#
#       Trans                                     UndergradMajor  \
# 0        No  Computer science, computer engineering, or sof...
# 1       NaN  Computer science, computer engineering, or sof...
# 2       NaN                                                NaN
# 3        No  Computer science, computer engineering, or sof...
# 4        No  Computer science, computer engineering, or sof...
# ...     ...                                                ...
# 64456   NaN  Computer science, computer engineering, or sof...
# 64457   NaN                                                NaN
# 64458   NaN                                                NaN
# 64459   NaN                                                NaN
# 64460   NaN  Computer science, computer engineering, or sof...
#
#             WebframeDesireNextYear                      WebframeWorkedWith  \
# 0                     ASP.NET Core                    ASP.NET;ASP.NET Core
# 1                              NaN                                     NaN
# 2                              NaN                                     NaN
# 3                              NaN                                     NaN
# 4             Django;Ruby on Rails                           Ruby on Rails
# ...                            ...                                     ...
# 64456                          NaN                                     NaN
# 64457                          NaN                                     NaN
# 64458                          NaN                                     NaN
# 64459  Angular;Angular.js;React.js                                     NaN
# 64460          ASP.NET Core;jQuery  Angular;Angular.js;ASP.NET Core;jQuery
#
#                                   WelcomeChange WorkWeekHrs YearsCode  \
# 0       Just as welcome now as I felt last year        50.0        36
# 1      Somewhat more welcome now than last year         NaN         7
# 2      Somewhat more welcome now than last year         NaN         4
# 3      Somewhat less welcome now than last year        40.0         7
# 4       Just as welcome now as I felt last year         NaN        15
# ...                                         ...         ...       ...
# 64456                                       NaN         NaN        10
# 64457                                       NaN         NaN       NaN
# 64458                                       NaN         NaN       NaN
# 64459                                       NaN         NaN       NaN
# 64460                                       NaN         NaN       NaN
#
#            YearsCodePro
# 0                    27
# 1                     4
# 2                   NaN
# 3                     4
# 4                     8
# ...                 ...
# 64456  Less than 1 year
# 64457               NaN
# 64458               NaN
# 64459               NaN
# 64460               NaN
#
# [64461 rows x 61 columns]

# %%
# Get a specific values form the DataFrame

d_country = data_f[data_f.Country == 'France']
d_country
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 14             15             I am a student who is learning to code      Yes
# 36             37                     I am a developer by profession      Yes
# 44             45                     I am a developer by profession      Yes
# 45             46                     I am a developer by profession      Yes
# 68             69                     I am a developer by profession      Yes
# ...           ...                                                ...      ...
# 63963       65424                     I am a developer by profession      Yes
# 64001       65464  I am not primarily a developer, but I write co...      Yes
# 64088       65559  I am not primarily a developer, but I write co...      Yes
# 64254       25321                                                NaN      Yes
# 64433       61561                                                NaN      Yes
#
#         Age Age1stCode CompFreq  CompTotal  ConvertedComp Country  \
# 14      NaN         13      NaN        NaN            NaN  France
# 36     19.0         16  Monthly        NaN            NaN  France
# 44     22.0         13   Yearly    34000.0        36753.0  France
# 45     24.0         14   Yearly    35000.0        37834.0  France
# 68     25.0         12   Yearly   550000.0       594539.0  France
# ...     ...        ...      ...        ...            ...     ...
# 63963   NaN         13      NaN        NaN            NaN  France
# 64001   NaN        NaN      NaN        NaN            NaN  France
# 64088   NaN         12      NaN        NaN            NaN  France
# 64254  41.0         18      NaN        NaN            NaN  France
# 64433  64.0         18      NaN        NaN            NaN  France
#
#         CurrencyDesc  ...                  SurveyEase           SurveyLength  \
# 14               NaN  ...                        Easy  Appropriate in length
# 36     European Euro  ...                        Easy               Too long
# 44     European Euro  ...                        Easy               Too long
# 45     European Euro  ...  Neither easy nor difficult  Appropriate in length
# 68     European Euro  ...                        Easy              Too short
# ...              ...  ...                         ...                    ...
# 63963  European Euro  ...                         NaN                    NaN
# 64001            NaN  ...                         NaN                    NaN
# 64088  European Euro  ...                         NaN                    NaN
# 64254            NaN  ...                        Easy  Appropriate in length
# 64433            NaN  ...  Neither easy nor difficult  Appropriate in length
#
#       Trans                                     UndergradMajor  \
# 14       No  Computer science, computer engineering, or sof...
# 36       No                      Web development or web design
# 44       No  Computer science, computer engineering, or sof...
# 45       No  Computer science, computer engineering, or sof...
# 68       No  Computer science, computer engineering, or sof...
# ...     ...                                                ...
# 63963   NaN  Computer science, computer engineering, or sof...
# 64001   NaN                                                NaN
# 64088   NaN  Computer science, computer engineering, or sof...
# 64254    No  Computer science, computer engineering, or sof...
# 64433    No  Information systems, information technology, o...
#
#                   WebframeDesireNextYear              WebframeWorkedWith  \
# 14                                   NaN                             NaN
# 36                                Gatsby  Express;jQuery;React.js;Vue.js
# 44                         Angular;Flask     Angular;Flask;jQuery;Spring
# 45                                   NaN                             NaN
# 68                          Django;Flask                    Django;Flask
# ...                                  ...                             ...
# 63963            Express;Gatsby;React.js         Express;Gatsby;React.js
# 64001                                NaN                             NaN
# 64088                                NaN                             NaN
# 64254                       Django;Flask                             NaN
# 64433  Angular.js;jQuery;React.js;Vue.js                          jQuery
#
#                                            WelcomeChange WorkWeekHrs  \
# 14               Just as welcome now as I felt last year         NaN
# 36              Somewhat more welcome now than last year        39.0
# 44                 A lot less welcome now than last year        35.0
# 45              Somewhat more welcome now than last year        35.0
# 68               Just as welcome now as I felt last year        40.0
# ...                                                  ...         ...
# 63963            Just as welcome now as I felt last year         NaN
# 64001            Just as welcome now as I felt last year         NaN
# 64088  Not applicable - I did not use Stack Overflow ...         NaN
# 64254            Just as welcome now as I felt last year         NaN
# 64433              A lot more welcome now than last year         NaN
#
#       YearsCode YearsCodePro
# 14            4          NaN
# 36            2            1
# 44            9            2
# 45            6            4
# 68           13            3
# ...         ...          ...
# 63963        20           10
# 64001       NaN          NaN
# 64088        12            3
# 64254        22           19
# 64433        30          NaN
#
# [1898 rows x 61 columns]

# %%
# Set the cloumns and row display size

pd.set_option('display.max_columns',85)

pd.set_option('display.max_rows', 85)

# %%
# Display certain number of values

# From Top / Head
data_f.head(10)

# if number is not provided it returns 5 values only

# From bottom / Tail
data_f.tail(10)
# Out:
#        Respondent MainBranch Hobbyist  Age Age1stCode CompFreq  CompTotal  \
# 64451       64104        NaN      Yes  NaN         19      NaN        NaN
# 64452       64236        NaN      Yes  NaN        NaN      NaN        NaN
# 64453       64330        NaN      Yes  NaN          5      NaN        NaN
# 64454       64480        NaN      Yes  NaN         21      NaN        NaN
# 64455       64567        NaN      Yes  NaN        NaN      NaN        NaN
# 64456       64858        NaN      Yes  NaN         16      NaN        NaN
# 64457       64867        NaN      Yes  NaN        NaN      NaN        NaN
# 64458       64898        NaN      Yes  NaN        NaN      NaN        NaN
# 64459       64925        NaN      Yes  NaN        NaN      NaN        NaN
# 64460       65112        NaN      Yes  NaN        NaN      NaN        NaN
#
#        ConvertedComp        Country CurrencyDesc CurrencySymbol  \
# 64451            NaN         Poland          NaN            NaN
# 64452            NaN          India          NaN            NaN
# 64453            NaN       Thailand          NaN            NaN
# 64454            NaN        Morocco          NaN            NaN
# 64455            NaN    Netherlands          NaN            NaN
# 64456            NaN  United States          NaN            NaN
# 64457            NaN        Morocco          NaN            NaN
# 64458            NaN       Viet Nam          NaN            NaN
# 64459            NaN         Poland          NaN            NaN
# 64460            NaN          Spain          NaN            NaN
#
#                                   DatabaseDesireNextYear  \
# 64451                                                NaN
# 64452                                                NaN
# 64453                                                NaN
# 64454                                                NaN
# 64455                               Microsoft SQL Server
# 64456                                                NaN
# 64457  Cassandra;Couchbase;DynamoDB;Elasticsearch;Fir...
# 64458                                                NaN
# 64459    DynamoDB;Elasticsearch;MongoDB;MySQL;PostgreSQL
# 64460                       MariaDB;Microsoft SQL Server
#
#                                       DatabaseWorkedWith  \
# 64451                                                NaN
# 64452                                                NaN
# 64453                                                NaN
# 64454                                                NaN
# 64455                                                NaN
# 64456                                                NaN
# 64457  Cassandra;Couchbase;DynamoDB;Elasticsearch;Fir...
# 64458                                                NaN
# 64459                                             Oracle
# 64460          MariaDB;Microsoft SQL Server;MySQL;Oracle
#
#                                                  DevType  \
# 64451      Data scientist or machine learning specialist
# 64452                                                NaN
# 64453  Data or business analyst;Developer, mobile;Sen...
# 64454                                                NaN
# 64455                                                NaN
# 64456                                Senior executive/VP
# 64457                                                NaN
# 64458                                                NaN
# 64459                                                NaN
# 64460                                                NaN
#
#                                                EdLevel  \
# 64451  Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 64452                                              NaN
# 64453                        Primary/elementary school
# 64454           I never completed any formal education
# 64455                                              NaN
# 64456  Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 64457                                              NaN
# 64458                        Primary/elementary school
# 64459                                              NaN
# 64460       Other doctoral degree (Ph.D., Ed.D., etc.)
#
#                                Employment Ethnicity Gender JobFactors JobSat  \
# 64451  Not employed, but looking for work       NaN    NaN        NaN    NaN
# 64452                  Employed full-time       NaN    NaN        NaN    NaN
# 64453  Not employed, but looking for work       NaN    NaN        NaN    NaN
# 64454                             Student       NaN    NaN        NaN    NaN
# 64455  Not employed, but looking for work       NaN    NaN        NaN    NaN
# 64456                  Employed full-time       NaN    NaN        NaN    NaN
# 64457                  Employed full-time       NaN    NaN        NaN    NaN
# 64458                                 NaN       NaN    NaN        NaN    NaN
# 64459                  Employed full-time       NaN    NaN        NaN    NaN
# 64460                  Employed full-time       NaN    NaN        NaN    NaN
#
#       JobSeek                             LanguageDesireNextYear  \
# 64451     NaN                                                NaN
# 64452     NaN                                                NaN
# 64453     NaN                                       C++;HTML/CSS
# 64454     NaN                                                NaN
# 64455     NaN                                               Java
# 64456     NaN                                                NaN
# 64457     NaN  Assembly;Bash/Shell/PowerShell;C;C#;C++;Dart;G...
# 64458     NaN                                                NaN
# 64459     NaN                           HTML/CSS;Java;JavaScript
# 64460     NaN                    C#;HTML/CSS;Java;JavaScript;SQL
#
#                                       LanguageWorkedWith  \
# 64451                                                NaN
# 64452                                                NaN
# 64453                                       C++;HTML/CSS
# 64454                                                NaN
# 64455                                                NaN
# 64456                                                NaN
# 64457  Assembly;Bash/Shell/PowerShell;C;C#;C++;Dart;G...
# 64458                                                NaN
# 64459                                           HTML/CSS
# 64460                    C#;HTML/CSS;Java;JavaScript;SQL
#
#       MiscTechDesireNextYear MiscTechWorkedWith NEWCollabToolsDesireNextYear  \
# 64451                    NaN                NaN                          NaN
# 64452                    NaN                NaN                          NaN
# 64453                   .NET               .NET                          NaN
# 64454                    NaN                NaN                          NaN
# 64455                Ansible                NaN                          NaN
# 64456                    NaN                NaN                          NaN
# 64457                    NaN                NaN                          NaN
# 64458                    NaN                NaN                          NaN
# 64459                Node.js                NaN                Github;Gitlab
# 64460      .NET Core;Xamarin     .NET;.NET Core       Github;Microsoft Teams
#
#                     NEWCollabToolsWorkedWith NEWDevOps NEWDevOpsImpt  \
# 64451                                    NaN       NaN           NaN
# 64452                                    NaN       NaN           NaN
# 64453                                    NaN       NaN           NaN
# 64454                                    NaN       NaN           NaN
# 64455                                 Github       NaN           NaN
# 64456                                    NaN       NaN           NaN
# 64457                                    NaN       NaN           NaN
# 64458                                    NaN       NaN           NaN
# 64459  Confluence;Jira;Slack;Microsoft Teams       NaN           NaN
# 64460                                 Github       NaN           NaN
#
#                   NEWEdImpt NEWJobHunt NEWJobHuntResearch       NEWLearn  \
# 64451      Fairly important        NaN                NaN            NaN
# 64452                   NaN        NaN                NaN            NaN
# 64453        Very important        NaN                NaN    Once a year
# 64454                   NaN        NaN                NaN            NaN
# 64455                   NaN        NaN                NaN            NaN
# 64456        Very important        NaN                NaN  Once a decade
# 64457                   NaN        NaN                NaN            NaN
# 64458                   NaN        NaN                NaN            NaN
# 64459                   NaN        NaN                NaN    Once a year
# 64460  Critically important        NaN                NaN    Once a year
#
#       NEWOffTopic NEWOnboardGood NEWOtherComms NEWOvertime  \
# 64451         NaN            NaN           NaN         NaN
# 64452         NaN            NaN           NaN         NaN
# 64453         NaN            NaN           NaN         NaN
# 64454         NaN            NaN           NaN         NaN
# 64455         NaN            NaN           NaN         NaN
# 64456         NaN            NaN           NaN         NaN
# 64457         NaN            NaN           NaN         NaN
# 64458         NaN            NaN           NaN         NaN
# 64459         NaN            NaN           NaN         NaN
# 64460         NaN            NaN           NaN         NaN
#
#                                      NEWPurchaseResearch      NEWPurpleLink  \
# 64451                                                NaN                NaN
# 64452                                                NaN                NaN
# 64453                                 Start a free trial  Hello, old friend
# 64454                                                NaN                NaN
# 64455                                                NaN                NaN
# 64456                                 Start a free trial             Amused
# 64457                                                NaN                NaN
# 64458                                                NaN                NaN
# 64459                                 Start a free trial  Hello, old friend
# 64460  Start a free trial;Ask developers I know/work ...        Indifferent
#
#                                               NEWSOSites  \
# 64451   Stack Overflow (public Q&A for anyone who codes)
# 64452                                                NaN
# 64453  Stack Overflow for Teams (private Q&A for orga...
# 64454   Stack Overflow (public Q&A for anyone who codes)
# 64455                                                NaN
# 64456   Stack Overflow (public Q&A for anyone who codes)
# 64457                                                NaN
# 64458                                                NaN
# 64459   Stack Overflow (public Q&A for anyone who codes)
# 64460                                                NaN
#
#                                                 NEWStuck    OpSys OrgSize  \
# 64451                                                NaN      NaN     NaN
# 64452                                                NaN      NaN     NaN
# 64453                       Watch help / tutorial videos    MacOS     NaN
# 64454                                                NaN      NaN     NaN
# 64455                                                NaN      NaN     NaN
# 64456                          Call a coworker or friend  Windows     NaN
# 64457                                                NaN      NaN     NaN
# 64458                                                NaN      NaN     NaN
# 64459     Call a coworker or friend;Visit Stack Overflow  Windows     NaN
# 64460  Meditate;Visit Stack Overflow;Go for a walk or...  Windows     NaN
#
#                    PlatformDesireNextYear  \
# 64451                                 NaN
# 64452                                 NaN
# 64453                                 iOS
# 64454                                 NaN
# 64455                             Android
# 64456                                 NaN
# 64457                                 NaN
# 64458                                 NaN
# 64459                                 NaN
# 64460  Arduino;Linux;Raspberry Pi;Windows
#
#                                PlatformWorkedWith PurchaseWhat Sexuality  \
# 64451                                         NaN          NaN       NaN
# 64452                                         NaN          NaN       NaN
# 64453                                         iOS          NaN       NaN
# 64454                                         NaN          NaN       NaN
# 64455                                         NaN          NaN       NaN
# 64456                                         NaN          NaN       NaN
# 64457                                         NaN          NaN       NaN
# 64458                                         NaN          NaN       NaN
# 64459                               Linux;Windows          NaN       NaN
# 64460  Android;Arduino;Linux;Raspberry Pi;Windows          NaN       NaN
#
#                      SOAccount          SOComm SOPartFreq  \
# 64451                      Yes             NaN        NaN
# 64452                      NaN             NaN        NaN
# 64453                      NaN             NaN        NaN
# 64454  Not sure/can't remember  No, not really        NaN
# 64455                      NaN             NaN        NaN
# 64456                      NaN             NaN        NaN
# 64457                      NaN             NaN        NaN
# 64458                      NaN             NaN        NaN
# 64459                      NaN             NaN        NaN
# 64460                      NaN             NaN        NaN
#
#                                SOVisitFreq SurveyEase SurveyLength Trans  \
# 64451      A few times per month or weekly        NaN          NaN   NaN
# 64452                                  NaN        NaN          NaN   NaN
# 64453                                  NaN        NaN          NaN   NaN
# 64454  Less than once per month or monthly        NaN          NaN   NaN
# 64455                                  NaN        NaN          NaN   NaN
# 64456                                  NaN        NaN          NaN   NaN
# 64457                                  NaN        NaN          NaN   NaN
# 64458                                  NaN        NaN          NaN   NaN
# 64459                                  NaN        NaN          NaN   NaN
# 64460                                  NaN        NaN          NaN   NaN
#
#                                           UndergradMajor  \
# 64451  Another engineering discipline (such as civil,...
# 64452                                                NaN
# 64453                                                NaN
# 64454                                                NaN
# 64455                                                NaN
# 64456  Computer science, computer engineering, or sof...
# 64457                                                NaN
# 64458                                                NaN
# 64459                                                NaN
# 64460  Computer science, computer engineering, or sof...
#
#             WebframeDesireNextYear                      WebframeWorkedWith  \
# 64451                          NaN                                     NaN
# 64452                          NaN                                     NaN
# 64453                          NaN                                     NaN
# 64454                          NaN                                     NaN
# 64455                          NaN                            ASP.NET Core
# 64456                          NaN                                     NaN
# 64457                          NaN                                     NaN
# 64458                          NaN                                     NaN
# 64459  Angular;Angular.js;React.js                                     NaN
# 64460          ASP.NET Core;jQuery  Angular;Angular.js;ASP.NET Core;jQuery
#
#                                  WelcomeChange  WorkWeekHrs YearsCode  \
# 64451                                      NaN          NaN         2
# 64452                                      NaN          NaN       NaN
# 64453                                      NaN          NaN         3
# 64454  Just as welcome now as I felt last year          NaN         3
# 64455                                      NaN          NaN       NaN
# 64456                                      NaN          NaN        10
# 64457                                      NaN          NaN       NaN
# 64458                                      NaN          NaN       NaN
# 64459                                      NaN          NaN       NaN
# 64460                                      NaN          NaN       NaN
#
#            YearsCodePro
# 64451               NaN
# 64452               NaN
# 64453               NaN
# 64454               NaN
# 64455               NaN
# 64456  Less than 1 year
# 64457               NaN
# 64458               NaN
# 64459               NaN
# 64460               NaN

# %%
# Get the shape of a dataframe
data_f.shape
# d_country.shape
# Out:
# (64461, 61)

# %%
# Get info

data_f.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64461 entries, 0 to 64460
# Data columns (total 61 columns):
# Respondent                      64461 non-null int64
# MainBranch                      64162 non-null object
# Hobbyist                        64416 non-null object
# Age                             45446 non-null float64
# Age1stCode                      57900 non-null object
# CompFreq                        40069 non-null object
# CompTotal                       34826 non-null float64
# ConvertedComp                   34756 non-null float64
# Country                         64072 non-null object
# CurrencyDesc                    45472 non-null object
# CurrencySymbol                  45472 non-null object
# DatabaseDesireNextYear          44070 non-null object
# DatabaseWorkedWith              49537 non-null object
# DevType                         49370 non-null object
# EdLevel                         57431 non-null object
# Employment                      63854 non-null object
# Ethnicity                       45948 non-null object
# Gender                          50557 non-null object
# JobFactors                      49349 non-null object
# JobSat                          45194 non-null object
# JobSeek                         51727 non-null object
# LanguageDesireNextYear          54113 non-null object
# LanguageWorkedWith              57378 non-null object
# MiscTechDesireNextYear          42379 non-null object
# MiscTechWorkedWith              40314 non-null object
# NEWCollabToolsDesireNextYear    47287 non-null object
# NEWCollabToolsWorkedWith        52883 non-null object
# NEWDevOps                       42686 non-null object
# NEWDevOpsImpt                   41732 non-null object
# NEWEdImpt                       48465 non-null object
# NEWJobHunt                      42286 non-null object
# NEWJobHuntResearch              41022 non-null object
# NEWLearn                        56156 non-null object
# NEWOffTopic                     50804 non-null object
# NEWOnboardGood                  42623 non-null object
# NEWOtherComms                   57205 non-null object
# NEWOvertime                     43231 non-null object
# NEWPurchaseResearch             37321 non-null object
# NEWPurpleLink                   54803 non-null object
# NEWSOSites                      58275 non-null object
# NEWStuck                        54983 non-null object
# OpSys                           56228 non-null object
# OrgSize                         44334 non-null object
# PlatformDesireNextYear          50605 non-null object
# PlatformWorkedWith              53843 non-null object
# PurchaseWhat                    39364 non-null object
# Sexuality                       43992 non-null object
# SOAccount                       56805 non-null object
# SOComm                          56476 non-null object
# SOPartFreq                      46792 non-null object
# SOVisitFreq                     56970 non-null object
# SurveyEase                      51802 non-null object
# SurveyLength                    51701 non-null object
# Trans                           49345 non-null object
# UndergradMajor                  50995 non-null object
# WebframeDesireNextYear          40024 non-null object
# WebframeWorkedWith              42279 non-null object
# WelcomeChange                   52683 non-null object
# WorkWeekHrs                     41151 non-null float64
# YearsCode                       57684 non-null object
# YearsCodePro                    46349 non-null object
# dtypes: float64(4), int64(1), object(56)
# memory usage: 30.0+ MB

# %%
data_f.head()
# Out:
#    Respondent                                         MainBranch Hobbyist  \
# 0           1                     I am a developer by profession      Yes
# 1           2                     I am a developer by profession       No
# 2           3                        I code primarily as a hobby      Yes
# 3           4                     I am a developer by profession      Yes
# 4           5  I used to be a developer by profession, but no...      Yes
#
#     Age Age1stCode CompFreq  CompTotal  ConvertedComp             Country  \
# 0   NaN         13  Monthly        NaN            NaN             Germany
# 1   NaN         19      NaN        NaN            NaN      United Kingdom
# 2   NaN         15      NaN        NaN            NaN  Russian Federation
# 3  25.0         18      NaN        NaN            NaN             Albania
# 4  31.0         16      NaN        NaN            NaN       United States
#
#      CurrencyDesc CurrencySymbol DatabaseDesireNextYear  \
# 0   European Euro            EUR   Microsoft SQL Server
# 1  Pound sterling            GBP                    NaN
# 2             NaN            NaN                    NaN
# 3    Albanian lek            ALL                    NaN
# 4             NaN            NaN       MySQL;PostgreSQL
#
#                           DatabaseWorkedWith  \
# 0  Elasticsearch;Microsoft SQL Server;Oracle
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4              MySQL;PostgreSQL;Redis;SQLite
#
#                                              DevType  \
# 0  Developer, desktop or enterprise applications;...
# 1            Developer, full-stack;Developer, mobile
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                            EdLevel  \
# 0  Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 1     Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 2                                              NaN
# 3  Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 4     Bachelor’s degree (B.A., B.S., B.Eng., etc.)
#
#                                           Employment  \
# 0  Independent contractor, freelancer, or self-em...
# 1                                 Employed full-time
# 2                                                NaN
# 3                                                NaN
# 4                                 Employed full-time
#
#                       Ethnicity Gender  \
# 0  White or of European descent    Man
# 1                           NaN    NaN
# 2                           NaN    NaN
# 3  White or of European descent    Man
# 4  White or of European descent    Man
#
#                                           JobFactors                 JobSat  \
# 0  Languages, frameworks, and other technologies ...     Slightly satisfied
# 1                                                NaN      Very dissatisfied
# 2                                                NaN                    NaN
# 3  Flex time or a flexible schedule;Office enviro...  Slightly dissatisfied
# 4                                                NaN                    NaN
#
#                                              JobSeek  \
# 0       I am not interested in new job opportunities
# 1       I am not interested in new job opportunities
# 2                                                NaN
# 3  I’m not actively looking, but I am open to new...
# 4                                                NaN
#
#      LanguageDesireNextYear        LanguageWorkedWith  \
# 0    C#;HTML/CSS;JavaScript    C#;HTML/CSS;JavaScript
# 1              Python;Swift          JavaScript;Swift
# 2  Objective-C;Python;Swift  Objective-C;Python;Swift
# 3                       NaN                       NaN
# 4           Java;Ruby;Scala         HTML/CSS;Ruby;SQL
#
#              MiscTechDesireNextYear MiscTechWorkedWith  \
# 0                 .NET Core;Xamarin     .NET;.NET Core
# 1  React Native;TensorFlow;Unity 3D       React Native
# 2                               NaN                NaN
# 3                               NaN                NaN
# 4                      Ansible;Chef            Ansible
#
#              NEWCollabToolsDesireNextYear  \
# 0  Microsoft Teams;Microsoft Azure;Trello
# 1                            Github;Slack
# 2                                     NaN
# 3                                     NaN
# 4   Github;Google Suite (Docs, Meet, etc)
#
#                             NEWCollabToolsWorkedWith NEWDevOps  \
# 0       Confluence;Jira;Slack;Microsoft Azure;Trello        No
# 1                Confluence;Jira;Github;Gitlab;Slack       NaN
# 2                                                NaN       NaN
# 3                                                NaN        No
# 4  Confluence;Jira;Github;Slack;Google Suite (Doc...       NaN
#
#         NEWDevOpsImpt                           NEWEdImpt  \
# 0  Somewhat important                    Fairly important
# 1                 NaN                    Fairly important
# 2                 NaN                                 NaN
# 3                 NaN  Not at all important/not necessary
# 4                 NaN                      Very important
#
#                                           NEWJobHunt NEWJobHuntResearch  \
# 0                                                NaN                NaN
# 1                                                NaN                NaN
# 2                                                NaN                NaN
# 3  Curious about other opportunities;Wanting to w...                NaN
# 4                                                NaN                NaN
#
#         NEWLearn NEWOffTopic NEWOnboardGood NEWOtherComms  \
# 0    Once a year    Not sure            NaN            No
# 1    Once a year    Not sure            NaN            No
# 2  Once a decade         NaN            NaN            No
# 3    Once a year    Not sure            Yes           Yes
# 4    Once a year          No            NaN           Yes
#
#                                          NEWOvertime  \
# 0                   Often: 1-2 days per week or more
# 1                                                NaN
# 2                                                NaN
# 3  Occasionally: 1-2 days per quarter but less th...
# 4                                                NaN
#
#                                  NEWPurchaseResearch      NEWPurpleLink  \
# 0  Start a free trial;Ask developers I know/work ...             Amused
# 1                                                NaN             Amused
# 2                                                NaN                NaN
# 3                                                NaN                NaN
# 4  Start a free trial;Ask developers I know/work ...  Hello, old friend
#
#                                           NEWSOSites  \
# 0   Stack Overflow (public Q&A for anyone who codes)
# 1  Stack Overflow (public Q&A for anyone who code...
# 2   Stack Overflow (public Q&A for anyone who codes)
# 3  Stack Overflow (public Q&A for anyone who code...
# 4  Stack Overflow (public Q&A for anyone who code...
#
#                                             NEWStuck        OpSys  \
# 0  Visit Stack Overflow;Go for a walk or other ph...      Windows
# 1  Visit Stack Overflow;Go for a walk or other ph...        MacOS
# 2                                                NaN  Linux-based
# 3                                                NaN  Linux-based
# 4  Call a coworker or friend;Visit Stack Overflow...      Windows
#
#                     OrgSize  \
# 0          2 to 9 employees
# 1  1,000 to 4,999 employees
# 2                       NaN
# 3        20 to 99 employees
# 4                       NaN
#
#                               PlatformDesireNextYear  \
# 0     Android;iOS;Kubernetes;Microsoft Azure;Windows
# 1                         iOS;Kubernetes;Linux;MacOS
# 2                                                NaN
# 3                                                NaN
# 4  Docker;Google Cloud Platform;Heroku;Linux;Windows
#
#                PlatformWorkedWith                      PurchaseWhat  \
# 0                         Windows                               NaN
# 1                             iOS     I have little or no influence
# 2                             NaN                               NaN
# 3                             NaN  I have a great deal of influence
# 4  AWS;Docker;Linux;MacOS;Windows                               NaN
#
#                  Sexuality SOAccount           SOComm  \
# 0  Straight / Heterosexual        No   No, not at all
# 1                      NaN       Yes  Yes, definitely
# 2                      NaN       Yes    Yes, somewhat
# 3  Straight / Heterosexual       Yes  Yes, definitely
# 4  Straight / Heterosexual       Yes    Yes, somewhat
#
#                             SOPartFreq                      SOVisitFreq  \
# 0                                  NaN           Multiple times per day
# 1  Less than once per month or monthly           Multiple times per day
# 2      A few times per month or weekly            Daily or almost daily
# 3      A few times per month or weekly           Multiple times per day
# 4  Less than once per month or monthly  A few times per month or weekly
#
#                    SurveyEase           SurveyLength Trans  \
# 0  Neither easy nor difficult  Appropriate in length    No
# 1                         NaN                    NaN   NaN
# 2  Neither easy nor difficult  Appropriate in length   NaN
# 3                         NaN                    NaN    No
# 4                        Easy              Too short    No
#
#                                       UndergradMajor WebframeDesireNextYear  \
# 0  Computer science, computer engineering, or sof...           ASP.NET Core
# 1  Computer science, computer engineering, or sof...                    NaN
# 2                                                NaN                    NaN
# 3  Computer science, computer engineering, or sof...                    NaN
# 4  Computer science, computer engineering, or sof...   Django;Ruby on Rails
#
#      WebframeWorkedWith                             WelcomeChange  \
# 0  ASP.NET;ASP.NET Core   Just as welcome now as I felt last year
# 1                   NaN  Somewhat more welcome now than last year
# 2                   NaN  Somewhat more welcome now than last year
# 3                   NaN  Somewhat less welcome now than last year
# 4         Ruby on Rails   Just as welcome now as I felt last year
#
#    WorkWeekHrs YearsCode YearsCodePro
# 0         50.0        36           27
# 1          NaN         7            4
# 2          NaN         4          NaN
# 3         40.0         7            4
# 4          NaN        15            8

# %%
schema_f
# Out:
#                           Column  \
# 0                     Respondent
# 1                     MainBranch
# 2                       Hobbyist
# 3                            Age
# 4                     Age1stCode
# 5                       CompFreq
# 6                      CompTotal
# 7                  ConvertedComp
# 8                        Country
# 9                   CurrencyDesc
# 10                CurrencySymbol
# 11        DatabaseDesireNextYear
# 12            DatabaseWorkedWith
# 13                       DevType
# 14                       EdLevel
# 15                    Employment
# 16                     Ethnicity
# 17                        Gender
# 18                    JobFactors
# 19                        JobSat
# 20                       JobSeek
# 21        LanguageDesireNextYear
# 22            LanguageWorkedWith
# 23        MiscTechDesireNextYear
# 24            MiscTechWorkedWith
# 25  NEWCollabToolsDesireNextYear
# 26      NEWCollabToolsWorkedWith
# 27                     NEWDevOps
# 28                 NEWDevOpsImpt
# 29                     NEWEdImpt
# 30                    NEWJobHunt
# 31            NEWJobHuntResearch
# 32                      NEWLearn
# 33                   NEWOffTopic
# 34                NEWOnboardGood
# 35                 NEWOtherComms
# 36                   NEWOvertime
# 37           NEWPurchaseResearch
# 38                 NEWPurpleLink
# 39                    NEWSOSites
# 40                      NEWStuck
# 41                         OpSys
# 42                       OrgSize
# 43        PlatformDesireNextYear
# 44            PlatformWorkedWith
# 45                  PurchaseWhat
# 46                     Sexuality
# 47                     SOAccount
# 48                        SOComm
# 49                    SOPartFreq
# 50                   SOVisitFreq
# 51                    SurveyEase
# 52                  SurveyLength
# 53                         Trans
# 54                UndergradMajor
# 55        WebframeDesireNextYear
# 56            WebframeWorkedWith
# 57                 WelcomeChange
# 58                   WorkWeekHrs
# 59                     YearsCode
# 60                  YearsCodePro
#
#                                          QuestionText
# 0   Randomized respondent ID number (not in order ...
# 1   Which of the following options best describes ...
# 2                             Do you code as a hobby?
# 3   What is your age (in years)? If you prefer not...
# 4   At what age did you write your first line of c...
# 5    Is that compensation weekly, monthly, or yearly?
# 6   What is your current total compensation (salar...
# 7   Salary converted to annual USD salaries using ...
# 8                                  Where do you live?
# 9   Which currency do you use day-to-day? If your ...
# 10  Which currency do you use day-to-day? If your ...
# 11  Which database environments have you done exte...
# 12  Which database environments have you done exte...
# 13  Which of the following describe you? Please se...
# 14  Which of the following best describes the high...
# 15  Which of the following best describes your cur...
# 16  Which of the following describe you, if any? P...
# 17  Which of the following describe you, if any? P...
# 18  Imagine that you are deciding between two job ...
# 19  How satisfied are you with your current job? (...
# 20  Which of the following best describes your cur...
# 21  Which programming, scripting, and markup langu...
# 22  Which programming, scripting, and markup langu...
# 23  Which other frameworks, libraries, and tools h...
# 24  Which other frameworks, libraries, and tools h...
# 25  Which collaboration tools have you done extens...
# 26  Which collaboration tools have you done extens...
# 27  Does your company have a dedicated DevOps person?
# 28  How important is the practice of DevOps to sca...
# 29  How important is a formal education, such as a...
# 30  In general, what drives you to look for a new ...
# 31  When job searching, how do you learn more abou...
# 32  How frequently do you learn a new language or ...
# 33  Do you think Stack Overflow should relax restr...
# 34  Do you think your company has a good onboardin...
# 35  Are you a member of any other online developer...
# 36  How often do you work overtime or beyond the f...
# 37  When buying a new tool or software, how do you...
# 38  You search for a coding solution online and th...
# 39  Which of the following Stack Overflow sites ha...
# 40  What do you do when you get stuck on a problem...
# 41  What is the primary operating system in which ...
# 42  Approximately how many people are employed by ...
# 43  Which platforms have you done extensive develo...
# 44  Which platforms have you done extensive develo...
# 45  What level of influence do you, personally, ha...
# 46  Which of the following describe you, if any? P...
# 47              Do you have a Stack Overflow account?
# 48  Do you consider yourself a member of the Stack...
# 49  How frequently would you say you participate i...
# 50  How frequently would you say you visit Stack O...
# 51  How easy or difficult was this survey to compl...
# 52  How do you feel about the length of the survey...
# 53                               Are you transgender?
# 54              What was your primary field of study?
# 55  Which web frameworks have you done extensive d...
# 56  Which web frameworks have you done extensive d...
# 57  Compared to last year, how welcome do you feel...
# 58  On average, how many hours per week do you wor...
# 59  Including any education, how many years have y...
# 60  NOT including education, how many years have y...

# %%
data_f.head()
# Out:
#    Respondent                                         MainBranch Hobbyist  \
# 0           1                     I am a developer by profession      Yes
# 1           2                     I am a developer by profession       No
# 2           3                        I code primarily as a hobby      Yes
# 3           4                     I am a developer by profession      Yes
# 4           5  I used to be a developer by profession, but no...      Yes
#
#     Age Age1stCode CompFreq  CompTotal  ConvertedComp             Country  \
# 0   NaN         13  Monthly        NaN            NaN             Germany
# 1   NaN         19      NaN        NaN            NaN      United Kingdom
# 2   NaN         15      NaN        NaN            NaN  Russian Federation
# 3  25.0         18      NaN        NaN            NaN             Albania
# 4  31.0         16      NaN        NaN            NaN       United States
#
#      CurrencyDesc CurrencySymbol DatabaseDesireNextYear  \
# 0   European Euro            EUR   Microsoft SQL Server
# 1  Pound sterling            GBP                    NaN
# 2             NaN            NaN                    NaN
# 3    Albanian lek            ALL                    NaN
# 4             NaN            NaN       MySQL;PostgreSQL
#
#                           DatabaseWorkedWith  \
# 0  Elasticsearch;Microsoft SQL Server;Oracle
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4              MySQL;PostgreSQL;Redis;SQLite
#
#                                              DevType  \
# 0  Developer, desktop or enterprise applications;...
# 1            Developer, full-stack;Developer, mobile
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                            EdLevel  \
# 0  Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 1     Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 2                                              NaN
# 3  Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 4     Bachelor’s degree (B.A., B.S., B.Eng., etc.)
#
#                                           Employment  \
# 0  Independent contractor, freelancer, or self-em...
# 1                                 Employed full-time
# 2                                                NaN
# 3                                                NaN
# 4                                 Employed full-time
#
#                       Ethnicity Gender  \
# 0  White or of European descent    Man
# 1                           NaN    NaN
# 2                           NaN    NaN
# 3  White or of European descent    Man
# 4  White or of European descent    Man
#
#                                           JobFactors                 JobSat  \
# 0  Languages, frameworks, and other technologies ...     Slightly satisfied
# 1                                                NaN      Very dissatisfied
# 2                                                NaN                    NaN
# 3  Flex time or a flexible schedule;Office enviro...  Slightly dissatisfied
# 4                                                NaN                    NaN
#
#                                              JobSeek  \
# 0       I am not interested in new job opportunities
# 1       I am not interested in new job opportunities
# 2                                                NaN
# 3  I’m not actively looking, but I am open to new...
# 4                                                NaN
#
#      LanguageDesireNextYear        LanguageWorkedWith  \
# 0    C#;HTML/CSS;JavaScript    C#;HTML/CSS;JavaScript
# 1              Python;Swift          JavaScript;Swift
# 2  Objective-C;Python;Swift  Objective-C;Python;Swift
# 3                       NaN                       NaN
# 4           Java;Ruby;Scala         HTML/CSS;Ruby;SQL
#
#              MiscTechDesireNextYear MiscTechWorkedWith  \
# 0                 .NET Core;Xamarin     .NET;.NET Core
# 1  React Native;TensorFlow;Unity 3D       React Native
# 2                               NaN                NaN
# 3                               NaN                NaN
# 4                      Ansible;Chef            Ansible
#
#              NEWCollabToolsDesireNextYear  \
# 0  Microsoft Teams;Microsoft Azure;Trello
# 1                            Github;Slack
# 2                                     NaN
# 3                                     NaN
# 4   Github;Google Suite (Docs, Meet, etc)
#
#                             NEWCollabToolsWorkedWith NEWDevOps  \
# 0       Confluence;Jira;Slack;Microsoft Azure;Trello        No
# 1                Confluence;Jira;Github;Gitlab;Slack       NaN
# 2                                                NaN       NaN
# 3                                                NaN        No
# 4  Confluence;Jira;Github;Slack;Google Suite (Doc...       NaN
#
#         NEWDevOpsImpt                           NEWEdImpt  \
# 0  Somewhat important                    Fairly important
# 1                 NaN                    Fairly important
# 2                 NaN                                 NaN
# 3                 NaN  Not at all important/not necessary
# 4                 NaN                      Very important
#
#                                           NEWJobHunt NEWJobHuntResearch  \
# 0                                                NaN                NaN
# 1                                                NaN                NaN
# 2                                                NaN                NaN
# 3  Curious about other opportunities;Wanting to w...                NaN
# 4                                                NaN                NaN
#
#         NEWLearn NEWOffTopic NEWOnboardGood NEWOtherComms  \
# 0    Once a year    Not sure            NaN            No
# 1    Once a year    Not sure            NaN            No
# 2  Once a decade         NaN            NaN            No
# 3    Once a year    Not sure            Yes           Yes
# 4    Once a year          No            NaN           Yes
#
#                                          NEWOvertime  \
# 0                   Often: 1-2 days per week or more
# 1                                                NaN
# 2                                                NaN
# 3  Occasionally: 1-2 days per quarter but less th...
# 4                                                NaN
#
#                                  NEWPurchaseResearch      NEWPurpleLink  \
# 0  Start a free trial;Ask developers I know/work ...             Amused
# 1                                                NaN             Amused
# 2                                                NaN                NaN
# 3                                                NaN                NaN
# 4  Start a free trial;Ask developers I know/work ...  Hello, old friend
#
#                                           NEWSOSites  \
# 0   Stack Overflow (public Q&A for anyone who codes)
# 1  Stack Overflow (public Q&A for anyone who code...
# 2   Stack Overflow (public Q&A for anyone who codes)
# 3  Stack Overflow (public Q&A for anyone who code...
# 4  Stack Overflow (public Q&A for anyone who code...
#
#                                             NEWStuck        OpSys  \
# 0  Visit Stack Overflow;Go for a walk or other ph...      Windows
# 1  Visit Stack Overflow;Go for a walk or other ph...        MacOS
# 2                                                NaN  Linux-based
# 3                                                NaN  Linux-based
# 4  Call a coworker or friend;Visit Stack Overflow...      Windows
#
#                     OrgSize  \
# 0          2 to 9 employees
# 1  1,000 to 4,999 employees
# 2                       NaN
# 3        20 to 99 employees
# 4                       NaN
#
#                               PlatformDesireNextYear  \
# 0     Android;iOS;Kubernetes;Microsoft Azure;Windows
# 1                         iOS;Kubernetes;Linux;MacOS
# 2                                                NaN
# 3                                                NaN
# 4  Docker;Google Cloud Platform;Heroku;Linux;Windows
#
#                PlatformWorkedWith                      PurchaseWhat  \
# 0                         Windows                               NaN
# 1                             iOS     I have little or no influence
# 2                             NaN                               NaN
# 3                             NaN  I have a great deal of influence
# 4  AWS;Docker;Linux;MacOS;Windows                               NaN
#
#                  Sexuality SOAccount           SOComm  \
# 0  Straight / Heterosexual        No   No, not at all
# 1                      NaN       Yes  Yes, definitely
# 2                      NaN       Yes    Yes, somewhat
# 3  Straight / Heterosexual       Yes  Yes, definitely
# 4  Straight / Heterosexual       Yes    Yes, somewhat
#
#                             SOPartFreq                      SOVisitFreq  \
# 0                                  NaN           Multiple times per day
# 1  Less than once per month or monthly           Multiple times per day
# 2      A few times per month or weekly            Daily or almost daily
# 3      A few times per month or weekly           Multiple times per day
# 4  Less than once per month or monthly  A few times per month or weekly
#
#                    SurveyEase           SurveyLength Trans  \
# 0  Neither easy nor difficult  Appropriate in length    No
# 1                         NaN                    NaN   NaN
# 2  Neither easy nor difficult  Appropriate in length   NaN
# 3                         NaN                    NaN    No
# 4                        Easy              Too short    No
#
#                                       UndergradMajor WebframeDesireNextYear  \
# 0  Computer science, computer engineering, or sof...           ASP.NET Core
# 1  Computer science, computer engineering, or sof...                    NaN
# 2                                                NaN                    NaN
# 3  Computer science, computer engineering, or sof...                    NaN
# 4  Computer science, computer engineering, or sof...   Django;Ruby on Rails
#
#      WebframeWorkedWith                             WelcomeChange  \
# 0  ASP.NET;ASP.NET Core   Just as welcome now as I felt last year
# 1                   NaN  Somewhat more welcome now than last year
# 2                   NaN  Somewhat more welcome now than last year
# 3                   NaN  Somewhat less welcome now than last year
# 4         Ruby on Rails   Just as welcome now as I felt last year
#
#    WorkWeekHrs YearsCode YearsCodePro
# 0         50.0        36           27
# 1          NaN         7            4
# 2          NaN         4          NaN
# 3         40.0         7            4
# 4          NaN        15            8

# %%
# List all columns
data_f.columns
# Out:
# Index(['Respondent', 'MainBranch', 'Hobbyist', 'Age', 'Age1stCode', 'CompFreq',
#        'CompTotal', 'ConvertedComp', 'Country', 'CurrencyDesc',
#        'CurrencySymbol', 'DatabaseDesireNextYear', 'DatabaseWorkedWith',
#        'DevType', 'EdLevel', 'Employment', 'Ethnicity', 'Gender', 'JobFactors',
#        'JobSat', 'JobSeek', 'LanguageDesireNextYear', 'LanguageWorkedWith',
#        'MiscTechDesireNextYear', 'MiscTechWorkedWith',
#        'NEWCollabToolsDesireNextYear', 'NEWCollabToolsWorkedWith', 'NEWDevOps',
#        'NEWDevOpsImpt', 'NEWEdImpt', 'NEWJobHunt', 'NEWJobHuntResearch',
#        'NEWLearn', 'NEWOffTopic', 'NEWOnboardGood', 'NEWOtherComms',
#        'NEWOvertime', 'NEWPurchaseResearch', 'NEWPurpleLink', 'NEWSOSites',
#        'NEWStuck', 'OpSys', 'OrgSize', 'PlatformDesireNextYear',
#        'PlatformWorkedWith', 'PurchaseWhat', 'Sexuality', 'SOAccount',
#        'SOComm', 'SOPartFreq', 'SOVisitFreq', 'SurveyEase', 'SurveyLength',
#        'Trans', 'UndergradMajor', 'WebframeDesireNextYear',
#        'WebframeWorkedWith', 'WelcomeChange', 'WorkWeekHrs', 'YearsCode',
#        'YearsCodePro'],
#       dtype='object')

# %%
# Accessing specific columns
data_f[['Ethnicity','JobSeek','Country','OpSys']].head(20)
# Out:
#                        Ethnicity  \
# 0   White or of European descent
# 1                            NaN
# 2                            NaN
# 3   White or of European descent
# 4   White or of European descent
# 5   White or of European descent
# 6                            NaN
# 7   White or of European descent
# 8                            NaN
# 9   White or of European descent
# 10  White or of European descent
# 11  White or of European descent
# 12  White or of European descent
# 13  White or of European descent
# 14                           NaN
# 15  White or of European descent
# 16  White or of European descent
# 17  White or of European descent
# 18  White or of European descent
# 19        Hispanic or Latino/a/x
#
#                                               JobSeek             Country  \
# 0        I am not interested in new job opportunities             Germany
# 1        I am not interested in new job opportunities      United Kingdom
# 2                                                 NaN  Russian Federation
# 3   I’m not actively looking, but I am open to new...             Albania
# 4                                                 NaN       United States
# 5        I am not interested in new job opportunities             Germany
# 6   I’m not actively looking, but I am open to new...               India
# 7   I’m not actively looking, but I am open to new...       United States
# 8   I’m not actively looking, but I am open to new...             Tunisia
# 9   I’m not actively looking, but I am open to new...      United Kingdom
# 10                    I am actively looking for a job      United Kingdom
# 11  I’m not actively looking, but I am open to new...               Spain
# 12       I am not interested in new job opportunities         Netherlands
# 13  I’m not actively looking, but I am open to new...       United States
# 14  I’m not actively looking, but I am open to new...              France
# 15  I’m not actively looking, but I am open to new...      United Kingdom
# 16  I’m not actively looking, but I am open to new...       United States
# 17       I am not interested in new job opportunities       United States
# 18  I’m not actively looking, but I am open to new...       United States
# 19  I’m not actively looking, but I am open to new...               Spain
#
#           OpSys
# 0       Windows
# 1         MacOS
# 2   Linux-based
# 3   Linux-based
# 4       Windows
# 5       Windows
# 6       Windows
# 7   Linux-based
# 8       Windows
# 9       Windows
# 10      Windows
# 11      Windows
# 12        MacOS
# 13      Windows
# 14  Linux-based
# 15        MacOS
# 16      Windows
# 17  Linux-based
# 18      Windows
# 19      Windows

# %%
data_f.iloc[[0,2,1]]
# Out:
#    Respondent                      MainBranch Hobbyist  Age Age1stCode  \
# 0           1  I am a developer by profession      Yes  NaN         13
# 2           3     I code primarily as a hobby      Yes  NaN         15
# 1           2  I am a developer by profession       No  NaN         19
#
#   CompFreq  CompTotal  ConvertedComp             Country    CurrencyDesc  \
# 0  Monthly        NaN            NaN             Germany   European Euro
# 2      NaN        NaN            NaN  Russian Federation             NaN
# 1      NaN        NaN            NaN      United Kingdom  Pound sterling
#
#   CurrencySymbol DatabaseDesireNextYear  \
# 0            EUR   Microsoft SQL Server
# 2            NaN                    NaN
# 1            GBP                    NaN
#
#                           DatabaseWorkedWith  \
# 0  Elasticsearch;Microsoft SQL Server;Oracle
# 2                                        NaN
# 1                                        NaN
#
#                                              DevType  \
# 0  Developer, desktop or enterprise applications;...
# 2                                                NaN
# 1            Developer, full-stack;Developer, mobile
#
#                                            EdLevel  \
# 0  Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 2                                              NaN
# 1     Bachelor’s degree (B.A., B.S., B.Eng., etc.)
#
#                                           Employment  \
# 0  Independent contractor, freelancer, or self-em...
# 2                                                NaN
# 1                                 Employed full-time
#
#                       Ethnicity Gender  \
# 0  White or of European descent    Man
# 2                           NaN    NaN
# 1                           NaN    NaN
#
#                                           JobFactors              JobSat  \
# 0  Languages, frameworks, and other technologies ...  Slightly satisfied
# 2                                                NaN                 NaN
# 1                                                NaN   Very dissatisfied
#
#                                         JobSeek    LanguageDesireNextYear  \
# 0  I am not interested in new job opportunities    C#;HTML/CSS;JavaScript
# 2                                           NaN  Objective-C;Python;Swift
# 1  I am not interested in new job opportunities              Python;Swift
#
#          LanguageWorkedWith            MiscTechDesireNextYear  \
# 0    C#;HTML/CSS;JavaScript                 .NET Core;Xamarin
# 2  Objective-C;Python;Swift                               NaN
# 1          JavaScript;Swift  React Native;TensorFlow;Unity 3D
#
#   MiscTechWorkedWith            NEWCollabToolsDesireNextYear  \
# 0     .NET;.NET Core  Microsoft Teams;Microsoft Azure;Trello
# 2                NaN                                     NaN
# 1       React Native                            Github;Slack
#
#                        NEWCollabToolsWorkedWith NEWDevOps       NEWDevOpsImpt  \
# 0  Confluence;Jira;Slack;Microsoft Azure;Trello        No  Somewhat important
# 2                                           NaN       NaN                 NaN
# 1           Confluence;Jira;Github;Gitlab;Slack       NaN                 NaN
#
#           NEWEdImpt NEWJobHunt NEWJobHuntResearch       NEWLearn NEWOffTopic  \
# 0  Fairly important        NaN                NaN    Once a year    Not sure
# 2               NaN        NaN                NaN  Once a decade         NaN
# 1  Fairly important        NaN                NaN    Once a year    Not sure
#
#   NEWOnboardGood NEWOtherComms                       NEWOvertime  \
# 0            NaN            No  Often: 1-2 days per week or more
# 2            NaN            No                               NaN
# 1            NaN            No                               NaN
#
#                                  NEWPurchaseResearch NEWPurpleLink  \
# 0  Start a free trial;Ask developers I know/work ...        Amused
# 2                                                NaN           NaN
# 1                                                NaN        Amused
#
#                                           NEWSOSites  \
# 0   Stack Overflow (public Q&A for anyone who codes)
# 2   Stack Overflow (public Q&A for anyone who codes)
# 1  Stack Overflow (public Q&A for anyone who code...
#
#                                             NEWStuck        OpSys  \
# 0  Visit Stack Overflow;Go for a walk or other ph...      Windows
# 2                                                NaN  Linux-based
# 1  Visit Stack Overflow;Go for a walk or other ph...        MacOS
#
#                     OrgSize                          PlatformDesireNextYear  \
# 0          2 to 9 employees  Android;iOS;Kubernetes;Microsoft Azure;Windows
# 2                       NaN                                             NaN
# 1  1,000 to 4,999 employees                      iOS;Kubernetes;Linux;MacOS
#
#   PlatformWorkedWith                   PurchaseWhat                Sexuality  \
# 0            Windows                            NaN  Straight / Heterosexual
# 2                NaN                            NaN                      NaN
# 1                iOS  I have little or no influence                      NaN
#
#   SOAccount           SOComm                           SOPartFreq  \
# 0        No   No, not at all                                  NaN
# 2       Yes    Yes, somewhat      A few times per month or weekly
# 1       Yes  Yes, definitely  Less than once per month or monthly
#
#               SOVisitFreq                  SurveyEase           SurveyLength  \
# 0  Multiple times per day  Neither easy nor difficult  Appropriate in length
# 2   Daily or almost daily  Neither easy nor difficult  Appropriate in length
# 1  Multiple times per day                         NaN                    NaN
#
#   Trans                                     UndergradMajor  \
# 0    No  Computer science, computer engineering, or sof...
# 2   NaN                                                NaN
# 1   NaN  Computer science, computer engineering, or sof...
#
#   WebframeDesireNextYear    WebframeWorkedWith  \
# 0           ASP.NET Core  ASP.NET;ASP.NET Core
# 2                    NaN                   NaN
# 1                    NaN                   NaN
#
#                               WelcomeChange  WorkWeekHrs YearsCode  \
# 0   Just as welcome now as I felt last year         50.0        36
# 2  Somewhat more welcome now than last year          NaN         4
# 1  Somewhat more welcome now than last year          NaN         7
#
#   YearsCodePro
# 0           27
# 2          NaN
# 1            4

# %%
# Count values
data_f['OpSys'].value_counts()
# Out:
# Windows        27170
# Linux-based    14932
# MacOS          14075
# BSD               51
# Name: OpSys, dtype: int64

# %%
data_f['EdLevel'].value_counts()
# Out:
# Bachelor’s degree (B.A., B.S., B.Eng., etc.)                                          26542
# Master’s degree (M.A., M.S., M.Eng., MBA, etc.)                                       13112
# Some college/university study without earning a degree                                 7239
# Secondary school (e.g. American high school, German Realschule or Gymnasium, etc.)     4771
# Associate degree (A.A., A.S., etc.)                                                    1843
# Other doctoral degree (Ph.D., Ed.D., etc.)                                             1690
# Primary/elementary school                                                               941
# Professional degree (JD, MD, etc.)                                                      800
# I never completed any formal education                                                  493
# Name: EdLevel, dtype: int64

# %%
data_f.loc[[5,6,7],'OpSys']
# Out:
# 5        Windows
# 6        Windows
# 7    Linux-based
# Name: OpSys, dtype: object

# %%
# Slicing
data_f.loc[50:100,['OpSys','EdLevel']]
# Out:
#            OpSys                                            EdLevel
# 50         MacOS  Some college/university study without earning ...
# 51         MacOS       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 52         MacOS  Secondary school (e.g. American high school, G...
# 53       Windows       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 54       Windows                Associate degree (A.A., A.S., etc.)
# 55         MacOS       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 56       Windows    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 57       Windows                                                NaN
# 58       Windows       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 59   Linux-based                                                NaN
# 60       Windows       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 61       Windows  Some college/university study without earning ...
# 62       Windows  Secondary school (e.g. American high school, G...
# 63   Linux-based  Some college/university study without earning ...
# 64       Windows       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 65   Linux-based                                                NaN
# 66   Linux-based                 Professional degree (JD, MD, etc.)
# 67       Windows  Some college/university study without earning ...
# 68         MacOS    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 69       Windows                                                NaN
# 70   Linux-based    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 71         MacOS       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 72   Linux-based       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 73   Linux-based       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 74         MacOS       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 75       Windows  Some college/university study without earning ...
# 76   Linux-based         Other doctoral degree (Ph.D., Ed.D., etc.)
# 77       Windows       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 78       Windows                                                NaN
# 79       Windows       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 80       Windows  Secondary school (e.g. American high school, G...
# 81       Windows                Associate degree (A.A., A.S., etc.)
# 82   Linux-based  Secondary school (e.g. American high school, G...
# 83       Windows       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 84       Windows  Some college/university study without earning ...
# 85         MacOS       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 86       Windows       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 87         MacOS  Some college/university study without earning ...
# 88         MacOS       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 89   Linux-based  Some college/university study without earning ...
# 90   Linux-based       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 91       Windows         Other doctoral degree (Ph.D., Ed.D., etc.)
# 92   Linux-based  Some college/university study without earning ...
# 93       Windows  Some college/university study without earning ...
# 94   Linux-based       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 95         MacOS       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 96       Windows    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 97       Windows       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 98       Windows                Associate degree (A.A., A.S., etc.)
# 99   Linux-based       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 100        MacOS    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)

# %%
# Slicing
data_f.loc[100:150,'Age':'Country']
# Out:
#       Age Age1stCode CompFreq   CompTotal  ConvertedComp  \
# 100  37.0         10      NaN         NaN            NaN
# 101  20.0         15      NaN         NaN            NaN
# 102  38.0         16  Monthly         NaN            NaN
# 103  28.0         16   Yearly     40000.0        40000.0
# 104  24.0         12  Monthly      3550.0        46044.0
# 105  29.0         13   Yearly    148000.0       148000.0
# 106   NaN         30      NaN         NaN            NaN
# 107   NaN         11      NaN         NaN            NaN
# 108  45.0         11   Yearly    130000.0       130000.0
# 109  25.0         20      NaN         NaN            NaN
# 110  28.0         16   Yearly     65000.0        65000.0
# 111  50.0         12      NaN         NaN            NaN
# 112   NaN          7      NaN         NaN            NaN
# 113  23.0         14   Yearly     78800.0        78800.0
# 114  38.0         13  Monthly         NaN            NaN
# 115  30.0         11   Yearly     90000.0       116333.0
# 116  20.0         11      NaN         NaN            NaN
# 117  35.0         15   Yearly    145000.0       145000.0
# 118  24.0         15   Yearly     57000.0        61616.0
# 119  26.0         19   Yearly    145000.0       145000.0
# 120  23.0         12   Yearly     85000.0       109871.0
# 121  26.0         12   Weekly    120000.0      2000000.0
# 122  38.0         14   Yearly         0.0            0.0
# 123  41.0         30  Monthly    200000.0      2000000.0
# 124  35.0         11   Yearly    145000.0       145000.0
# 125  64.0         15      NaN         NaN            NaN
# 126  23.0         14   Yearly     80000.0        80000.0
# 127   NaN         16   Yearly    115000.0       115000.0
# 128   NaN         15  Monthly         NaN            NaN
# 129  37.0         11   Yearly    115000.0       115000.0
# 130  38.0         13  Monthly      1200.0        15564.0
# 131   NaN         18   Yearly     45000.0        24864.0
# 132  30.0         10   Weekly      3250.0       210050.0
# 133  53.0         10      NaN         NaN            NaN
# 134   NaN         12      NaN         NaN            NaN
# 135  63.0         17   Yearly    120000.0       129718.0
# 136  25.0         18   Yearly    215000.0       215000.0
# 137  30.0         17   Yearly     45000.0        45000.0
# 138  49.0         13      NaN         NaN            NaN
# 139  23.0         16      NaN         NaN            NaN
# 140  27.0         25   Yearly     53000.0        53000.0
# 141  25.0         10   Yearly     97500.0        97500.0
# 142  32.0         14   Yearly     75000.0        75000.0
# 143  26.0         11   Yearly     25000.0        32315.0
# 144  33.0         12   Yearly    580000.0        59320.0
# 145  28.0         15   Yearly     50000.0        37816.0
# 146  34.0         13  Monthly      4200.0        54480.0
# 147  36.0         31   Yearly  21000000.0       293196.0
# 148   NaN         12   Yearly    300000.0       300000.0
# 149  35.0         10  Monthly     20000.0         9792.0
# 150  30.0         16  Monthly     10000.0       121980.0
#
#                     Country
# 100          United Kingdom
# 101           United States
# 102  Bosnia and Herzegovina
# 103           United States
# 104                 Germany
# 105           United States
# 106          United Kingdom
# 107           United States
# 108           United States
# 109                 Germany
# 110           United States
# 111           United States
# 112                  Canada
# 113           United States
# 114                   Spain
# 115          United Kingdom
# 116                   China
# 117           United States
# 118                 Germany
# 119           United States
# 120          United Kingdom
# 121           United States
# 122           United States
# 123           United States
# 124           United States
# 125           United States
# 126           United States
# 127           United States
# 128          United Kingdom
# 129           United States
# 130                   Spain
# 131                Bulgaria
# 132          United Kingdom
# 133           United States
# 134                  Canada
# 135                 Germany
# 136           United States
# 137           United States
# 138                  Canada
# 139                  Serbia
# 140           United States
# 141           United States
# 142           United States
# 143          United Kingdom
# 144                  Sweden
# 145                  Canada
# 146                 Germany
# 147                   India
# 148           United States
# 149                 Ukraine
# 150             Switzerland
