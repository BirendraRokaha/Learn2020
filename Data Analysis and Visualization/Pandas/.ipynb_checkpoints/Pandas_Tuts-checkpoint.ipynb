# %% [markdown]
# # Pandas Tutorial

# %%
# Importing the required libraries

import pandas as pd

# %% [markdown]
# ### Read a csv file and print

# %%
# Reading a csv file using pandas and assigning it to a variable/DataFrame

data_f = pd.read_csv("survey_results_public.csv")

# Print the DataFrame
data_f
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 0               1                     I am a developer by profession      Yes
# 1               2                     I am a developer by profession       No
# 2               3                        I code primarily as a hobby      Yes
# 3               4                     I am a developer by profession      Yes
# 4               5  I used to be a developer by profession, but no...      Yes
# ...           ...                                                ...      ...
# 64456       64858                                                NaN      Yes
# 64457       64867                                                NaN      Yes
# 64458       64898                                                NaN      Yes
# 64459       64925                                                NaN      Yes
# 64460       65112                                                NaN      Yes
#
#         Age Age1stCode CompFreq  CompTotal  ConvertedComp             Country  \
# 0       NaN         13  Monthly        NaN            NaN             Germany
# 1       NaN         19      NaN        NaN            NaN      United Kingdom
# 2       NaN         15      NaN        NaN            NaN  Russian Federation
# 3      25.0         18      NaN        NaN            NaN             Albania
# 4      31.0         16      NaN        NaN            NaN       United States
# ...     ...        ...      ...        ...            ...                 ...
# 64456   NaN         16      NaN        NaN            NaN       United States
# 64457   NaN        NaN      NaN        NaN            NaN             Morocco
# 64458   NaN        NaN      NaN        NaN            NaN            Viet Nam
# 64459   NaN        NaN      NaN        NaN            NaN              Poland
# 64460   NaN        NaN      NaN        NaN            NaN               Spain
#
#          CurrencyDesc  ...                  SurveyEase           SurveyLength  \
# 0       European Euro  ...  Neither easy nor difficult  Appropriate in length
# 1      Pound sterling  ...                         NaN                    NaN
# 2                 NaN  ...  Neither easy nor difficult  Appropriate in length
# 3        Albanian lek  ...                         NaN                    NaN
# 4                 NaN  ...                        Easy              Too short
# ...               ...  ...                         ...                    ...
# 64456             NaN  ...                         NaN                    NaN
# 64457             NaN  ...                         NaN                    NaN
# 64458             NaN  ...                         NaN                    NaN
# 64459             NaN  ...                         NaN                    NaN
# 64460             NaN  ...                         NaN                    NaN
#
#       Trans                                     UndergradMajor  \
# 0        No  Computer science, computer engineering, or sof...
# 1       NaN  Computer science, computer engineering, or sof...
# 2       NaN                                                NaN
# 3        No  Computer science, computer engineering, or sof...
# 4        No  Computer science, computer engineering, or sof...
# ...     ...                                                ...
# 64456   NaN  Computer science, computer engineering, or sof...
# 64457   NaN                                                NaN
# 64458   NaN                                                NaN
# 64459   NaN                                                NaN
# 64460   NaN  Computer science, computer engineering, or sof...
#
#             WebframeDesireNextYear                      WebframeWorkedWith  \
# 0                     ASP.NET Core                    ASP.NET;ASP.NET Core
# 1                              NaN                                     NaN
# 2                              NaN                                     NaN
# 3                              NaN                                     NaN
# 4             Django;Ruby on Rails                           Ruby on Rails
# ...                            ...                                     ...
# 64456                          NaN                                     NaN
# 64457                          NaN                                     NaN
# 64458                          NaN                                     NaN
# 64459  Angular;Angular.js;React.js                                     NaN
# 64460          ASP.NET Core;jQuery  Angular;Angular.js;ASP.NET Core;jQuery
#
#                                   WelcomeChange WorkWeekHrs YearsCode  \
# 0       Just as welcome now as I felt last year        50.0        36
# 1      Somewhat more welcome now than last year         NaN         7
# 2      Somewhat more welcome now than last year         NaN         4
# 3      Somewhat less welcome now than last year        40.0         7
# 4       Just as welcome now as I felt last year         NaN        15
# ...                                         ...         ...       ...
# 64456                                       NaN         NaN        10
# 64457                                       NaN         NaN       NaN
# 64458                                       NaN         NaN       NaN
# 64459                                       NaN         NaN       NaN
# 64460                                       NaN         NaN       NaN
#
#            YearsCodePro
# 0                    27
# 1                     4
# 2                   NaN
# 3                     4
# 4                     8
# ...                 ...
# 64456  Less than 1 year
# 64457               NaN
# 64458               NaN
# 64459               NaN
# 64460               NaN
#
# [64461 rows x 61 columns]

# %%
# Get a specific values form the DataFrame

d_country = data_f[data_f.Country == 'Australia']
d_country
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 399           401                     I am a developer by profession      Yes
# 2568         2581                     I am a developer by profession      Yes
# 2614         2627  I am not primarily a developer, but I write co...       No
# 3363         3377                     I am a developer by profession      Yes
# 3441         3455                     I am a developer by profession      Yes
# ...           ...                                                ...      ...
# 64252       24707                                                NaN      Yes
# 64288       35567                                                NaN      Yes
# 64355       45642                                                NaN      Yes
# 64373       50888                                                NaN      Yes
# 64446       63640                                                NaN      Yes
#
#         Age     Age1stCode CompFreq  CompTotal  ConvertedComp    Country  \
# 399    34.0             17   Yearly    70000.0        46767.0  Australia
# 2568   40.0             11      NaN        NaN            NaN  Australia
# 2614   38.0             18   Yearly   100000.0       108098.0  Australia
# 3363   27.0             17   Yearly   250000.0       167024.0  Australia
# 3441   39.0             15   Yearly   130000.0        86853.0  Australia
# ...     ...            ...      ...        ...            ...        ...
# 64252   NaN            NaN      NaN        NaN            NaN  Australia
# 64288   NaN  Older than 85      NaN        NaN            NaN  Australia
# 64355   NaN            NaN      NaN        NaN            NaN  Australia
# 64373  19.0             14      NaN        NaN            NaN  Australia
# 64446   NaN              8      NaN        NaN            NaN  Australia
#
#             CurrencyDesc CurrencySymbol  \
# 399    Australian dollar            AUD
# 2568   Australian dollar            AUD
# 2614       European Euro            EUR
# 3363   Australian dollar            AUD
# 3441   Australian dollar            AUD
# ...                  ...            ...
# 64252                NaN            NaN
# 64288                NaN            NaN
# 64355                NaN            NaN
# 64373                NaN            NaN
# 64446                NaN            NaN
#
#                                   DatabaseDesireNextYear  \
# 399    Elasticsearch;MariaDB;Microsoft SQL Server;MyS...
# 2568                                          PostgreSQL
# 2614                                                 NaN
# 3363                                               MySQL
# 3441                          Microsoft SQL Server;MySQL
# ...                                                  ...
# 64252  Cassandra;Couchbase;DynamoDB;Elasticsearch;Fir...
# 64288                                                NaN
# 64355                                                NaN
# 64373                                                NaN
# 64446  Firebase;Microsoft SQL Server;MongoDB;MySQL;Po...
#
#                                       DatabaseWorkedWith  \
# 399    Elasticsearch;MariaDB;Microsoft SQL Server;MyS...
# 2568             MariaDB;Microsoft SQL Server;PostgreSQL
# 2614                                                 NaN
# 3363                                               MySQL
# 3441                          Microsoft SQL Server;MySQL
# ...                                                  ...
# 64252        Cassandra;Couchbase;DynamoDB;IBM DB2;Oracle
# 64288                                                NaN
# 64355                                                NaN
# 64373                                                NaN
# 64446                                            MongoDB
#
#                                                  DevType  \
# 399    Database administrator;Developer, back-end;Dev...
# 2568   Developer, back-end;Developer, desktop or ente...
# 2614                                   DevOps specialist
# 3363                               Developer, full-stack
# 3441   Data or business analyst;Database administrato...
# ...                                                  ...
# 64252                                                NaN
# 64288                                                NaN
# 64355                                                NaN
# 64373  Developer, back-end;Developer, desktop or ente...
# 64446  Academic researcher;Data or business analyst;D...
#
#                                                  EdLevel  \
# 399         Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 2568        Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 2614     Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 3363        Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 3441        Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# ...                                                  ...
# 64252                 Professional degree (JD, MD, etc.)
# 64288    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 64355                                                NaN
# 64373  Some college/university study without earning ...
# 64446                          Primary/elementary school
#
#                                               Employment  \
# 399                                   Employed full-time
# 2568                                  Employed full-time
# 2614                                  Employed full-time
# 3363   Independent contractor, freelancer, or self-em...
# 3441                                  Employed full-time
# ...                                                  ...
# 64252                                                NaN
# 64288                                 Employed part-time
# 64355  Independent contractor, freelancer, or self-em...
# 64373                                 Employed part-time
# 64446  Independent contractor, freelancer, or self-em...
#
#                           Ethnicity  \
# 399                      East Asian
# 2568   White or of European descent
# 2614                            NaN
# 3363   White or of European descent
# 3441   White or of European descent
# ...                             ...
# 64252                           NaN
# 64288                           NaN
# 64355                           NaN
# 64373  White or of European descent
# 64446                           NaN
#
#                                                   Gender  \
# 399                                                Woman
# 2568                                                 Man
# 2614                                                 NaN
# 3363                                                 Man
# 3441                                                 Man
# ...                                                  ...
# 64252  Woman;Non-binary, genderqueer, or gender non-c...
# 64288                                                NaN
# 64355                                                NaN
# 64373                                              Woman
# 64446                                                Man
#
#                                               JobFactors  \
# 399    Flex time or a flexible schedule;Remote work o...
# 2568   Languages, frameworks, and other technologies ...
# 2614   Flex time or a flexible schedule;Specific depa...
# 3363   Languages, frameworks, and other technologies ...
# 3441   Languages, frameworks, and other technologies ...
# ...                                                  ...
# 64252                                                NaN
# 64288                                                NaN
# 64355                                                NaN
# 64373                                                NaN
# 64446                                                NaN
#
#                       JobSat  \
# 399           Very satisfied
# 2568      Slightly satisfied
# 2614   Slightly dissatisfied
# 3363          Very satisfied
# 3441          Very satisfied
# ...                      ...
# 64252                    NaN
# 64288                    NaN
# 64355                    NaN
# 64373                    NaN
# 64446                    NaN
#
#                                                  JobSeek  \
# 399    I’m not actively looking, but I am open to new...
# 2568   I’m not actively looking, but I am open to new...
# 2614   I’m not actively looking, but I am open to new...
# 3363        I am not interested in new job opportunities
# 3441   I’m not actively looking, but I am open to new...
# ...                                                  ...
# 64252                                                NaN
# 64288                                                NaN
# 64355                                                NaN
# 64373                                                NaN
# 64446                                                NaN
#
#                                   LanguageDesireNextYear  \
# 399         HTML/CSS;Java;JavaScript;PHP;Python;Ruby;SQL
# 2568   Bash/Shell/PowerShell;HTML/CSS;Java;JavaScript...
# 2614                                                Rust
# 3363                              C#;HTML/CSS;TypeScript
# 3441                      C#;C++;HTML/CSS;JavaScript;SQL
# ...                                                  ...
# 64252                                                NaN
# 64288                                                NaN
# 64355                                                NaN
# 64373            Bash/Shell/PowerShell;C++;HTML/CSS;Java
# 64446  Assembly;Bash/Shell/PowerShell;C;C#;C++;Dart;G...
#
#                                       LanguageWorkedWith  \
# 399      Go;HTML/CSS;Java;JavaScript;PHP;Python;Ruby;SQL
# 2568   Bash/Shell/PowerShell;C;C++;Dart;Go;HTML/CSS;J...
# 2614                          Bash/Shell/PowerShell;Java
# 3363                   C#;HTML/CSS;JavaScript;TypeScript
# 3441                      C#;C++;HTML/CSS;JavaScript;SQL
# ...                                                  ...
# 64252                                                NaN
# 64288                                                NaN
# 64355                                                NaN
# 64373                          Bash/Shell/PowerShell;C++
# 64446  Bash/Shell/PowerShell;C;C#;C++;HTML/CSS;Java;J...
#
#                                   MiscTechDesireNextYear  \
# 399                                                 Chef
# 2568                         Apache Spark;Hadoop;Node.js
# 2614                                    Ansible;Teraform
# 3363                                      .NET;.NET Core
# 3441                              .NET;.NET Core;Xamarin
# ...                                                  ...
# 64252  Puppet;TensorFlow;Teraform;Torch/PyTorch;Unity 3D
# 64288                                                NaN
# 64355                                                NaN
# 64373                                                NaN
# 64446  Flutter;Node.js;React Native;TensorFlow;Unity ...
#
#                                       MiscTechWorkedWith  \
# 399                                                 Chef
# 2568                                             Node.js
# 2614                                             Ansible
# 3363                              .NET;.NET Core;Node.js
# 3441                                                .NET
# ...                                                  ...
# 64252  .NET Core;Apache Spark;Flutter;Node.js;Puppet;...
# 64288                                                NaN
# 64355                                                NaN
# 64373                                                NaN
# 64446                     Node.js;Unity 3D;Unreal Engine
#
#                             NEWCollabToolsDesireNextYear  \
# 399    Github;Gitlab;Slack;Trello;Google Suite (Docs,...
# 2568                                        Github;Slack
# 2614                                              Github
# 3363                                                 NaN
# 3441              Github;Microsoft Teams;Microsoft Azure
# ...                                                  ...
# 64252  Gitlab;Facebook Workplace;Slack;Microsoft Team...
# 64288                                                NaN
# 64355                                                NaN
# 64373             Github;Gitlab;Stack Overflow for Teams
# 64446  Jira;Github;Slack;Microsoft Teams;Microsoft Az...
#
#                                 NEWCollabToolsWorkedWith NEWDevOps  \
# 399    Confluence;Jira;Github;Gitlab;Slack;Trello;Goo...       Yes
# 2568   Github;Slack;Microsoft Azure;Google Suite (Doc...        No
# 2614                              Confluence;Jira;Github       Yes
# 3363                                                 NaN        No
# 3441   Github;Microsoft Teams;Microsoft Azure;Google ...        No
# ...                                                  ...       ...
# 64252  Confluence;Github;Facebook Workplace;Slack;Mic...       NaN
# 64288                                                NaN       NaN
# 64355                                                NaN       NaN
# 64373             Github;Gitlab;Stack Overflow for Teams       NaN
# 64446  Github;Slack;Microsoft Azure;Google Suite (Doc...       NaN
#
#              NEWDevOpsImpt                           NEWEdImpt  \
# 399    Extremely important  Not at all important/not necessary
# 2568               Neutral                    Fairly important
# 2614   Extremely important                      Very important
# 3363    Somewhat important                Critically important
# 3441    Somewhat important  Not at all important/not necessary
# ...                    ...                                 ...
# 64252                  NaN                                 NaN
# 64288                  NaN  Not at all important/not necessary
# 64355                  NaN                                 NaN
# 64373                  NaN                    Fairly important
# 64446                  NaN                Critically important
#
#                                               NEWJobHunt  \
# 399         Better compensation;Better work/life balance
# 2568   Curious about other opportunities;Better compe...
# 2614   Curious about other opportunities;Growth or le...
# 3363                                        Just because
# 3441   Curious about other opportunities;Trouble with...
# ...                                                  ...
# 64252                                                NaN
# 64288                                                NaN
# 64355                                                NaN
# 64373                                                NaN
# 64446                                                NaN
#
#                                       NEWJobHuntResearch  \
# 399    Read company media, such as employee blogs or ...
# 2568   Read company media, such as employee blogs or ...
# 2614   Read company media, such as employee blogs or ...
# 3363                Personal network - friends or family
# 3441   Read company media, such as employee blogs or ...
# ...                                                  ...
# 64252                                                NaN
# 64288                                                NaN
# 64355                                                NaN
# 64373                                                NaN
# 64446                                                NaN
#
#                    NEWLearn NEWOffTopic                NEWOnboardGood  \
# 399    Once every few years          No                           Yes
# 2568       Every few months          No  Onboarding? What onboarding?
# 2614            Once a year    Not sure                            No
# 3363   Once every few years          No                           Yes
# 3441            Once a year    Not sure  Onboarding? What onboarding?
# ...                     ...         ...                           ...
# 64252                   NaN         Yes                           NaN
# 64288                   NaN         NaN                           NaN
# 64355                   NaN         NaN                           NaN
# 64373           Once a year    Not sure                           NaN
# 64446      Every few months          No                           NaN
#
#       NEWOtherComms                                        NEWOvertime  \
# 399             Yes                  Rarely: 1-2 days per year or less
# 2568            Yes  Sometimes: 1-2 days per month but less than we...
# 2614             No  Sometimes: 1-2 days per month but less than we...
# 3363             No                   Often: 1-2 days per week or more
# 3441             No  Sometimes: 1-2 days per month but less than we...
# ...             ...                                                ...
# 64252           NaN                                                NaN
# 64288           NaN                                                NaN
# 64355           NaN                                                NaN
# 64373           NaN                                                NaN
# 64446           NaN                                                NaN
#
#                                      NEWPurchaseResearch      NEWPurpleLink  \
# 399    Start a free trial;Ask developers I know/work ...  Hello, old friend
# 2568   Start a free trial;Ask developers I know/work ...  Hello, old friend
# 2614   Start a free trial;Ask developers I know/work ...        Indifferent
# 3363     Visit developer communities like Stack Overflow  Hello, old friend
# 3441   Start a free trial;Ask developers I know/work ...  Hello, old friend
# ...                                                  ...                ...
# 64252  Ask developers I know/work with;Visit develope...  Hello, old friend
# 64288                                                NaN                NaN
# 64355                                                NaN                NaN
# 64373  Start a free trial;Ask developers I know/work ...  Hello, old friend
# 64446  Start a free trial;Ask developers I know/work ...        Indifferent
#
#                                               NEWSOSites  \
# 399    Stack Overflow (public Q&A for anyone who code...
# 2568   Stack Overflow (public Q&A for anyone who code...
# 2614   Stack Overflow (public Q&A for anyone who code...
# 3363   Stack Overflow (public Q&A for anyone who code...
# 3441   Stack Overflow (public Q&A for anyone who code...
# ...                                                  ...
# 64252  Stack Overflow (public Q&A for anyone who code...
# 64288                                                NaN
# 64355                                                NaN
# 64373  Stack Overflow (public Q&A for anyone who code...
# 64446   Stack Overflow (public Q&A for anyone who codes)
#
#                                                 NEWStuck        OpSys  \
# 399    Visit Stack Overflow;Go for a walk or other ph...  Linux-based
# 2568   Call a coworker or friend;Visit Stack Overflow...  Linux-based
# 2614   Call a coworker or friend;Visit Stack Overflow...  Linux-based
# 3363                                Visit Stack Overflow      Windows
# 3441   Visit Stack Overflow;Do other work and come ba...      Windows
# ...                                                  ...          ...
# 64252  Meditate;Play games;Visit Stack Overflow;Go fo...        MacOS
# 64288                                                NaN          NaN
# 64355                                                NaN          NaN
# 64373  Call a coworker or friend;Visit Stack Overflow...  Linux-based
# 64446  Call a coworker or friend;Visit Stack Overflow...        MacOS
#
#                         OrgSize  \
# 399        100 to 499 employees
# 2568         20 to 99 employees
# 2614   10,000 or more employees
# 3363                        NaN
# 3441       500 to 999 employees
# ...                         ...
# 64252                       NaN
# 64288                       NaN
# 64355                       NaN
# 64373                       NaN
# 64446                       NaN
#
#                                   PlatformDesireNextYear  \
# 399                             Android;AWS;Docker;Linux
# 2568       Android;AWS;Docker;Linux;Raspberry Pi;Windows
# 2614                                          Kubernetes
# 3363                                                 NaN
# 3441   Arduino;Linux;Microsoft Azure;Raspberry Pi;Win...
# ...                                                  ...
# 64252                                                NaN
# 64288                                                NaN
# 64355                                                NaN
# 64373                                 Linux;Raspberry Pi
# 64446  Android;Arduino;AWS;Docker;Google Cloud Platfo...
#
#                                       PlatformWorkedWith  \
# 399    Android;AWS;Docker;iOS;Linux;MacOS;Slack Apps ...
# 2568   Android;AWS;Docker;Google Cloud Platform;Linux...
# 2614                                   Docker;Kubernetes
# 3363                                                 NaN
# 3441   Arduino;Linux;Microsoft Azure;Raspberry Pi;Win...
# ...                                                  ...
# 64252  Android;Docker;Google Cloud Platform;Kubernete...
# 64288                                                NaN
# 64355                                                NaN
# 64373                                      Linux;Windows
# 64446  AWS;Google Cloud Platform;Heroku;iOS;Linux;Mac...
#
#                            PurchaseWhat                Sexuality SOAccount  \
# 399    I have a great deal of influence           Gay or Lesbian       Yes
# 2568              I have some influence  Straight / Heterosexual       Yes
# 2614              I have some influence                      NaN       Yes
# 3363                                NaN  Straight / Heterosexual       Yes
# 3441   I have a great deal of influence  Straight / Heterosexual       Yes
# ...                                 ...                      ...       ...
# 64252                               NaN  Straight / Heterosexual       Yes
# 64288                               NaN                      NaN       NaN
# 64355                               NaN                      NaN       NaN
# 64373                               NaN           Gay or Lesbian       Yes
# 64446                               NaN  Straight / Heterosexual       Yes
#
#                 SOComm                                         SOPartFreq  \
# 399    Yes, definitely                             Multiple times per day
# 2568   Yes, definitely                               A few times per week
# 2614     Yes, somewhat                    A few times per month or weekly
# 3363   Yes, definitely                             Multiple times per day
# 3441    No, not at all                Less than once per month or monthly
# ...                ...                                                ...
# 64252  Yes, definitely                               A few times per week
# 64288              NaN                                                NaN
# 64355              NaN                                                NaN
# 64373   No, not really                Less than once per month or monthly
# 64446    Yes, somewhat  I have never participated in Q&A on Stack Over...
#
#                            SOVisitFreq                  SurveyEase  \
# 399              Daily or almost daily  Neither easy nor difficult
# 2568             Daily or almost daily                        Easy
# 2614              A few times per week                        Easy
# 3363            Multiple times per day                        Easy
# 3441              A few times per week                        Easy
# ...                                ...                         ...
# 64252            Daily or almost daily  Neither easy nor difficult
# 64288                              NaN                         NaN
# 64355                              NaN                         NaN
# 64373            Daily or almost daily                        Easy
# 64446  A few times per month or weekly                         NaN
#
#                 SurveyLength Trans  \
# 399                 Too long    No
# 2568   Appropriate in length    No
# 2614   Appropriate in length   NaN
# 3363   Appropriate in length    No
# 3441   Appropriate in length    No
# ...                      ...   ...
# 64252               Too long    No
# 64288                    NaN   NaN
# 64355                    NaN   NaN
# 64373  Appropriate in length    No
# 64446                    NaN    No
#
#                                           UndergradMajor  \
# 399    Computer science, computer engineering, or sof...
# 2568   Computer science, computer engineering, or sof...
# 2614   Information systems, information technology, o...
# 3363   Computer science, computer engineering, or sof...
# 3441   A social science (such as anthropology, psycho...
# ...                                                  ...
# 64252                                                NaN
# 64288                           I never declared a major
# 64355                                                NaN
# 64373  Computer science, computer engineering, or sof...
# 64446                                                NaN
#
#                                   WebframeDesireNextYear  \
# 399    Flask;jQuery;Laravel;React.js;Ruby on Rails;Sy...
# 2568                                     React.js;Spring
# 2614                                                 NaN
# 3363                        Angular;ASP.NET;ASP.NET Core
# 3441                                             ASP.NET
# ...                                                  ...
# 64252                                                NaN
# 64288                                                NaN
# 64355                                                NaN
# 64373                                                NaN
# 64446  Angular;Angular.js;Express;jQuery;React.js;Vue.js
#
#                                       WebframeWorkedWith  \
# 399    Angular.js;Flask;jQuery;Laravel;Ruby on Rails;...
# 2568                             Express;React.js;Spring
# 2614                                                 NaN
# 3363                 Angular;ASP.NET;ASP.NET Core;jQuery
# 3441                                             ASP.NET
# ...                                                  ...
# 64252                                    jQuery;React.js
# 64288                                                NaN
# 64355                                                NaN
# 64373                                                NaN
# 64446                                     Express;jQuery
#
#                                   WelcomeChange  WorkWeekHrs  \
# 399       A lot less welcome now than last year         30.0
# 2568    Just as welcome now as I felt last year         40.0
# 2614    Just as welcome now as I felt last year         40.0
# 3363    Just as welcome now as I felt last year         40.0
# 3441    Just as welcome now as I felt last year         50.0
# ...                                         ...          ...
# 64252  Somewhat more welcome now than last year          NaN
# 64288                                       NaN          NaN
# 64355                                       NaN          NaN
# 64373   Just as welcome now as I felt last year          NaN
# 64446  Somewhat more welcome now than last year          NaN
#
#                 YearsCode        YearsCodePro
# 399                    25                  20
# 2568                   29                  19
# 2614                   20                  10
# 3363                   10                   5
# 3441                   25                  10
# ...                   ...                 ...
# 64252                 NaN                 NaN
# 64288  More than 50 years  More than 50 years
# 64355                 NaN                 NaN
# 64373                   7                   1
# 64446                   6                   2
#
# [1208 rows x 61 columns]

# %%
# Display certain number of values

# From Top / Head
data_f.head(10)

# if number is not provided it returns 5 values only

# From bottom / Tail
data_f.tail(10)
# Out:
#        Respondent MainBranch Hobbyist  Age Age1stCode CompFreq  CompTotal  \
# 64451       64104        NaN      Yes  NaN         19      NaN        NaN
# 64452       64236        NaN      Yes  NaN        NaN      NaN        NaN
# 64453       64330        NaN      Yes  NaN          5      NaN        NaN
# 64454       64480        NaN      Yes  NaN         21      NaN        NaN
# 64455       64567        NaN      Yes  NaN        NaN      NaN        NaN
# 64456       64858        NaN      Yes  NaN         16      NaN        NaN
# 64457       64867        NaN      Yes  NaN        NaN      NaN        NaN
# 64458       64898        NaN      Yes  NaN        NaN      NaN        NaN
# 64459       64925        NaN      Yes  NaN        NaN      NaN        NaN
# 64460       65112        NaN      Yes  NaN        NaN      NaN        NaN
#
#        ConvertedComp        Country CurrencyDesc CurrencySymbol  \
# 64451            NaN         Poland          NaN            NaN
# 64452            NaN          India          NaN            NaN
# 64453            NaN       Thailand          NaN            NaN
# 64454            NaN        Morocco          NaN            NaN
# 64455            NaN    Netherlands          NaN            NaN
# 64456            NaN  United States          NaN            NaN
# 64457            NaN        Morocco          NaN            NaN
# 64458            NaN       Viet Nam          NaN            NaN
# 64459            NaN         Poland          NaN            NaN
# 64460            NaN          Spain          NaN            NaN
#
#                                   DatabaseDesireNextYear  \
# 64451                                                NaN
# 64452                                                NaN
# 64453                                                NaN
# 64454                                                NaN
# 64455                               Microsoft SQL Server
# 64456                                                NaN
# 64457  Cassandra;Couchbase;DynamoDB;Elasticsearch;Fir...
# 64458                                                NaN
# 64459    DynamoDB;Elasticsearch;MongoDB;MySQL;PostgreSQL
# 64460                       MariaDB;Microsoft SQL Server
#
#                                       DatabaseWorkedWith  \
# 64451                                                NaN
# 64452                                                NaN
# 64453                                                NaN
# 64454                                                NaN
# 64455                                                NaN
# 64456                                                NaN
# 64457  Cassandra;Couchbase;DynamoDB;Elasticsearch;Fir...
# 64458                                                NaN
# 64459                                             Oracle
# 64460          MariaDB;Microsoft SQL Server;MySQL;Oracle
#
#                                                  DevType  \
# 64451      Data scientist or machine learning specialist
# 64452                                                NaN
# 64453  Data or business analyst;Developer, mobile;Sen...
# 64454                                                NaN
# 64455                                                NaN
# 64456                                Senior executive/VP
# 64457                                                NaN
# 64458                                                NaN
# 64459                                                NaN
# 64460                                                NaN
#
#                                                EdLevel  \
# 64451  Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 64452                                              NaN
# 64453                        Primary/elementary school
# 64454           I never completed any formal education
# 64455                                              NaN
# 64456  Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 64457                                              NaN
# 64458                        Primary/elementary school
# 64459                                              NaN
# 64460       Other doctoral degree (Ph.D., Ed.D., etc.)
#
#                                Employment Ethnicity Gender JobFactors JobSat  \
# 64451  Not employed, but looking for work       NaN    NaN        NaN    NaN
# 64452                  Employed full-time       NaN    NaN        NaN    NaN
# 64453  Not employed, but looking for work       NaN    NaN        NaN    NaN
# 64454                             Student       NaN    NaN        NaN    NaN
# 64455  Not employed, but looking for work       NaN    NaN        NaN    NaN
# 64456                  Employed full-time       NaN    NaN        NaN    NaN
# 64457                  Employed full-time       NaN    NaN        NaN    NaN
# 64458                                 NaN       NaN    NaN        NaN    NaN
# 64459                  Employed full-time       NaN    NaN        NaN    NaN
# 64460                  Employed full-time       NaN    NaN        NaN    NaN
#
#       JobSeek                             LanguageDesireNextYear  \
# 64451     NaN                                                NaN
# 64452     NaN                                                NaN
# 64453     NaN                                       C++;HTML/CSS
# 64454     NaN                                                NaN
# 64455     NaN                                               Java
# 64456     NaN                                                NaN
# 64457     NaN  Assembly;Bash/Shell/PowerShell;C;C#;C++;Dart;G...
# 64458     NaN                                                NaN
# 64459     NaN                           HTML/CSS;Java;JavaScript
# 64460     NaN                    C#;HTML/CSS;Java;JavaScript;SQL
#
#                                       LanguageWorkedWith  \
# 64451                                                NaN
# 64452                                                NaN
# 64453                                       C++;HTML/CSS
# 64454                                                NaN
# 64455                                                NaN
# 64456                                                NaN
# 64457  Assembly;Bash/Shell/PowerShell;C;C#;C++;Dart;G...
# 64458                                                NaN
# 64459                                           HTML/CSS
# 64460                    C#;HTML/CSS;Java;JavaScript;SQL
#
#       MiscTechDesireNextYear MiscTechWorkedWith NEWCollabToolsDesireNextYear  \
# 64451                    NaN                NaN                          NaN
# 64452                    NaN                NaN                          NaN
# 64453                   .NET               .NET                          NaN
# 64454                    NaN                NaN                          NaN
# 64455                Ansible                NaN                          NaN
# 64456                    NaN                NaN                          NaN
# 64457                    NaN                NaN                          NaN
# 64458                    NaN                NaN                          NaN
# 64459                Node.js                NaN                Github;Gitlab
# 64460      .NET Core;Xamarin     .NET;.NET Core       Github;Microsoft Teams
#
#                     NEWCollabToolsWorkedWith NEWDevOps NEWDevOpsImpt  \
# 64451                                    NaN       NaN           NaN
# 64452                                    NaN       NaN           NaN
# 64453                                    NaN       NaN           NaN
# 64454                                    NaN       NaN           NaN
# 64455                                 Github       NaN           NaN
# 64456                                    NaN       NaN           NaN
# 64457                                    NaN       NaN           NaN
# 64458                                    NaN       NaN           NaN
# 64459  Confluence;Jira;Slack;Microsoft Teams       NaN           NaN
# 64460                                 Github       NaN           NaN
#
#                   NEWEdImpt NEWJobHunt NEWJobHuntResearch       NEWLearn  \
# 64451      Fairly important        NaN                NaN            NaN
# 64452                   NaN        NaN                NaN            NaN
# 64453        Very important        NaN                NaN    Once a year
# 64454                   NaN        NaN                NaN            NaN
# 64455                   NaN        NaN                NaN            NaN
# 64456        Very important        NaN                NaN  Once a decade
# 64457                   NaN        NaN                NaN            NaN
# 64458                   NaN        NaN                NaN            NaN
# 64459                   NaN        NaN                NaN    Once a year
# 64460  Critically important        NaN                NaN    Once a year
#
#       NEWOffTopic NEWOnboardGood NEWOtherComms NEWOvertime  \
# 64451         NaN            NaN           NaN         NaN
# 64452         NaN            NaN           NaN         NaN
# 64453         NaN            NaN           NaN         NaN
# 64454         NaN            NaN           NaN         NaN
# 64455         NaN            NaN           NaN         NaN
# 64456         NaN            NaN           NaN         NaN
# 64457         NaN            NaN           NaN         NaN
# 64458         NaN            NaN           NaN         NaN
# 64459         NaN            NaN           NaN         NaN
# 64460         NaN            NaN           NaN         NaN
#
#                                      NEWPurchaseResearch      NEWPurpleLink  \
# 64451                                                NaN                NaN
# 64452                                                NaN                NaN
# 64453                                 Start a free trial  Hello, old friend
# 64454                                                NaN                NaN
# 64455                                                NaN                NaN
# 64456                                 Start a free trial             Amused
# 64457                                                NaN                NaN
# 64458                                                NaN                NaN
# 64459                                 Start a free trial  Hello, old friend
# 64460  Start a free trial;Ask developers I know/work ...        Indifferent
#
#                                               NEWSOSites  \
# 64451   Stack Overflow (public Q&A for anyone who codes)
# 64452                                                NaN
# 64453  Stack Overflow for Teams (private Q&A for orga...
# 64454   Stack Overflow (public Q&A for anyone who codes)
# 64455                                                NaN
# 64456   Stack Overflow (public Q&A for anyone who codes)
# 64457                                                NaN
# 64458                                                NaN
# 64459   Stack Overflow (public Q&A for anyone who codes)
# 64460                                                NaN
#
#                                                 NEWStuck    OpSys OrgSize  \
# 64451                                                NaN      NaN     NaN
# 64452                                                NaN      NaN     NaN
# 64453                       Watch help / tutorial videos    MacOS     NaN
# 64454                                                NaN      NaN     NaN
# 64455                                                NaN      NaN     NaN
# 64456                          Call a coworker or friend  Windows     NaN
# 64457                                                NaN      NaN     NaN
# 64458                                                NaN      NaN     NaN
# 64459     Call a coworker or friend;Visit Stack Overflow  Windows     NaN
# 64460  Meditate;Visit Stack Overflow;Go for a walk or...  Windows     NaN
#
#                    PlatformDesireNextYear  \
# 64451                                 NaN
# 64452                                 NaN
# 64453                                 iOS
# 64454                                 NaN
# 64455                             Android
# 64456                                 NaN
# 64457                                 NaN
# 64458                                 NaN
# 64459                                 NaN
# 64460  Arduino;Linux;Raspberry Pi;Windows
#
#                                PlatformWorkedWith PurchaseWhat Sexuality  \
# 64451                                         NaN          NaN       NaN
# 64452                                         NaN          NaN       NaN
# 64453                                         iOS          NaN       NaN
# 64454                                         NaN          NaN       NaN
# 64455                                         NaN          NaN       NaN
# 64456                                         NaN          NaN       NaN
# 64457                                         NaN          NaN       NaN
# 64458                                         NaN          NaN       NaN
# 64459                               Linux;Windows          NaN       NaN
# 64460  Android;Arduino;Linux;Raspberry Pi;Windows          NaN       NaN
#
#                      SOAccount          SOComm SOPartFreq  \
# 64451                      Yes             NaN        NaN
# 64452                      NaN             NaN        NaN
# 64453                      NaN             NaN        NaN
# 64454  Not sure/can't remember  No, not really        NaN
# 64455                      NaN             NaN        NaN
# 64456                      NaN             NaN        NaN
# 64457                      NaN             NaN        NaN
# 64458                      NaN             NaN        NaN
# 64459                      NaN             NaN        NaN
# 64460                      NaN             NaN        NaN
#
#                                SOVisitFreq SurveyEase SurveyLength Trans  \
# 64451      A few times per month or weekly        NaN          NaN   NaN
# 64452                                  NaN        NaN          NaN   NaN
# 64453                                  NaN        NaN          NaN   NaN
# 64454  Less than once per month or monthly        NaN          NaN   NaN
# 64455                                  NaN        NaN          NaN   NaN
# 64456                                  NaN        NaN          NaN   NaN
# 64457                                  NaN        NaN          NaN   NaN
# 64458                                  NaN        NaN          NaN   NaN
# 64459                                  NaN        NaN          NaN   NaN
# 64460                                  NaN        NaN          NaN   NaN
#
#                                           UndergradMajor  \
# 64451  Another engineering discipline (such as civil,...
# 64452                                                NaN
# 64453                                                NaN
# 64454                                                NaN
# 64455                                                NaN
# 64456  Computer science, computer engineering, or sof...
# 64457                                                NaN
# 64458                                                NaN
# 64459                                                NaN
# 64460  Computer science, computer engineering, or sof...
#
#             WebframeDesireNextYear                      WebframeWorkedWith  \
# 64451                          NaN                                     NaN
# 64452                          NaN                                     NaN
# 64453                          NaN                                     NaN
# 64454                          NaN                                     NaN
# 64455                          NaN                            ASP.NET Core
# 64456                          NaN                                     NaN
# 64457                          NaN                                     NaN
# 64458                          NaN                                     NaN
# 64459  Angular;Angular.js;React.js                                     NaN
# 64460          ASP.NET Core;jQuery  Angular;Angular.js;ASP.NET Core;jQuery
#
#                                  WelcomeChange  WorkWeekHrs YearsCode  \
# 64451                                      NaN          NaN         2
# 64452                                      NaN          NaN       NaN
# 64453                                      NaN          NaN         3
# 64454  Just as welcome now as I felt last year          NaN         3
# 64455                                      NaN          NaN       NaN
# 64456                                      NaN          NaN        10
# 64457                                      NaN          NaN       NaN
# 64458                                      NaN          NaN       NaN
# 64459                                      NaN          NaN       NaN
# 64460                                      NaN          NaN       NaN
#
#            YearsCodePro
# 64451               NaN
# 64452               NaN
# 64453               NaN
# 64454               NaN
# 64455               NaN
# 64456  Less than 1 year
# 64457               NaN
# 64458               NaN
# 64459               NaN
# 64460               NaN

# %%
# Get the shape of a dataframe
data_f.shape
# d_country.shape
# Out:
# (64461, 61)

# %%
# Get info

data_f.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64461 entries, 0 to 64460
# Data columns (total 61 columns):
# Respondent                      64461 non-null int64
# MainBranch                      64162 non-null object
# Hobbyist                        64416 non-null object
# Age                             45446 non-null float64
# Age1stCode                      57900 non-null object
# CompFreq                        40069 non-null object
# CompTotal                       34826 non-null float64
# ConvertedComp                   34756 non-null float64
# Country                         64072 non-null object
# CurrencyDesc                    45472 non-null object
# CurrencySymbol                  45472 non-null object
# DatabaseDesireNextYear          44070 non-null object
# DatabaseWorkedWith              49537 non-null object
# DevType                         49370 non-null object
# EdLevel                         57431 non-null object
# Employment                      63854 non-null object
# Ethnicity                       45948 non-null object
# Gender                          50557 non-null object
# JobFactors                      49349 non-null object
# JobSat                          45194 non-null object
# JobSeek                         51727 non-null object
# LanguageDesireNextYear          54113 non-null object
# LanguageWorkedWith              57378 non-null object
# MiscTechDesireNextYear          42379 non-null object
# MiscTechWorkedWith              40314 non-null object
# NEWCollabToolsDesireNextYear    47287 non-null object
# NEWCollabToolsWorkedWith        52883 non-null object
# NEWDevOps                       42686 non-null object
# NEWDevOpsImpt                   41732 non-null object
# NEWEdImpt                       48465 non-null object
# NEWJobHunt                      42286 non-null object
# NEWJobHuntResearch              41022 non-null object
# NEWLearn                        56156 non-null object
# NEWOffTopic                     50804 non-null object
# NEWOnboardGood                  42623 non-null object
# NEWOtherComms                   57205 non-null object
# NEWOvertime                     43231 non-null object
# NEWPurchaseResearch             37321 non-null object
# NEWPurpleLink                   54803 non-null object
# NEWSOSites                      58275 non-null object
# NEWStuck                        54983 non-null object
# OpSys                           56228 non-null object
# OrgSize                         44334 non-null object
# PlatformDesireNextYear          50605 non-null object
# PlatformWorkedWith              53843 non-null object
# PurchaseWhat                    39364 non-null object
# Sexuality                       43992 non-null object
# SOAccount                       56805 non-null object
# SOComm                          56476 non-null object
# SOPartFreq                      46792 non-null object
# SOVisitFreq                     56970 non-null object
# SurveyEase                      51802 non-null object
# SurveyLength                    51701 non-null object
# Trans                           49345 non-null object
# UndergradMajor                  50995 non-null object
# WebframeDesireNextYear          40024 non-null object
# WebframeWorkedWith              42279 non-null object
# WelcomeChange                   52683 non-null object
# WorkWeekHrs                     41151 non-null float64
# YearsCode                       57684 non-null object
# YearsCodePro                    46349 non-null object
# dtypes: float64(4), int64(1), object(56)
# memory usage: 30.0+ MB

# %%
# Set the cloumns and row display size

pd.set_option('display.max_columns',85)

# pd.set_option('display.max_rows',100)
