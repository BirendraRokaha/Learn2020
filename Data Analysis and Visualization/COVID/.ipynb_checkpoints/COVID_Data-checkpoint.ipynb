# %% [markdown]
# # Working with COVID data

# %%
import sys                             # system module 
import numpy as np                     # number package
import pandas as pd                    # data package
from matplotlib import pyplot as plt   # graphics package
import datetime as dt                  # date and time module

# check versions (overkill, but why not?)
print(f'Python version: {sys.version}')
print(f'Numpy version: {np.__version__}')
print(f'Pandas version: {pd.__version__}')
# print(f'Matplotlib version: {plt.__version__}'
print(f'Today: {dt.date.today()}' )
# Out:
# Python version: 3.7.4 (default, Aug  9 2019, 18:34:13) [MSC v.1915 64 bit (AMD64)]
# Numpy version: 1.16.5
# Pandas version: 0.25.1
# Today: 2020-09-27

# %%
data_file = pd.read_csv('Covid_data.csv')
data_file
# Out:
#       iso_code continent       location        date  total_cases  new_cases  \
# 0          AFG      Asia    Afghanistan  2019-12-31          0.0        0.0
# 1          AFG      Asia    Afghanistan  2020-01-01          0.0        0.0
# 2          AFG      Asia    Afghanistan  2020-01-02          0.0        0.0
# 3          AFG      Asia    Afghanistan  2020-01-03          0.0        0.0
# 4          AFG      Asia    Afghanistan  2020-01-04          0.0        0.0
# ...        ...       ...            ...         ...          ...        ...
# 46479      NaN       NaN  International  2020-09-23        696.0        NaN
# 46480      NaN       NaN  International  2020-09-24        696.0        NaN
# 46481      NaN       NaN  International  2020-09-25        696.0        NaN
# 46482      NaN       NaN  International  2020-09-26        696.0        NaN
# 46483      NaN       NaN  International  2020-09-27        696.0        NaN
#
#        new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0                     NaN           0.0         0.0                  NaN  ...
# 1                     NaN           0.0         0.0                  NaN  ...
# 2                     NaN           0.0         0.0                  NaN  ...
# 3                     NaN           0.0         0.0                  NaN  ...
# 4                     NaN           0.0         0.0                  NaN  ...
# ...                   ...           ...         ...                  ...  ...
# 46479                 NaN           7.0         NaN                  NaN  ...
# 46480                 NaN           7.0         NaN                  NaN  ...
# 46481                 NaN           7.0         NaN                  NaN  ...
# 46482                 NaN           7.0         NaN                  NaN  ...
# 46483                 NaN           7.0         NaN                  NaN  ...
#
#        gdp_per_capita  extreme_poverty  cardiovasc_death_rate  \
# 0            1803.987              NaN                597.029
# 1            1803.987              NaN                597.029
# 2            1803.987              NaN                597.029
# 3            1803.987              NaN                597.029
# 4            1803.987              NaN                597.029
# ...               ...              ...                    ...
# 46479             NaN              NaN                    NaN
# 46480             NaN              NaN                    NaN
# 46481             NaN              NaN                    NaN
# 46482             NaN              NaN                    NaN
# 46483             NaN              NaN                    NaN
#
#        diabetes_prevalence  female_smokers  male_smokers  \
# 0                     9.59             NaN           NaN
# 1                     9.59             NaN           NaN
# 2                     9.59             NaN           NaN
# 3                     9.59             NaN           NaN
# 4                     9.59             NaN           NaN
# ...                    ...             ...           ...
# 46479                  NaN             NaN           NaN
# 46480                  NaN             NaN           NaN
# 46481                  NaN             NaN           NaN
# 46482                  NaN             NaN           NaN
# 46483                  NaN             NaN           NaN
#
#        handwashing_facilities  hospital_beds_per_thousand  life_expectancy  \
# 0                      37.746                         0.5            64.83
# 1                      37.746                         0.5            64.83
# 2                      37.746                         0.5            64.83
# 3                      37.746                         0.5            64.83
# 4                      37.746                         0.5            64.83
# ...                       ...                         ...              ...
# 46479                     NaN                         NaN              NaN
# 46480                     NaN                         NaN              NaN
# 46481                     NaN                         NaN              NaN
# 46482                     NaN                         NaN              NaN
# 46483                     NaN                         NaN              NaN
#
#        human_development_index
# 0                        0.498
# 1                        0.498
# 2                        0.498
# 3                        0.498
# 4                        0.498
# ...                        ...
# 46479                      NaN
# 46480                      NaN
# 46481                      NaN
# 46482                      NaN
# 46483                      NaN
#
# [46484 rows x 41 columns]

# %%
nepal = data_file[data_file.location == 'Nepal']

aus = data_file[data_file.location == 'Australia']

ind = data_file[data_file.location == 'India']

# %%
#Plot Graph for a Country


def plotcoutry(name):    
    c_name = data_file[data_file.location == name]
    
    plt.figure(figsize=(20,10))
    # Getting the data to plot
    
    plt.plot(c_name.date,c_name.total_cases)
    plt.plot(c_name.date,c_name.new_cases)
    
    # labelling
    plt.title(f"Covid chart {name}")
    plt.xlabel("Date")
    plt.ylabel("Number")
    plt.legend(['Total','New'])
    # Display
    plt.show()
    
plotcoutry('New Zealand')

# %%
# Compare Total cases of Two countries

def total_compare(name1,name2):    
    a_name = data_file[data_file.location == name1]
    b_name = data_file[data_file.location == name2]
    
    plt.figure(figsize=(20,10))
    # Getting the data to plot
    
    plt.plot(a_name.date,a_name.total_cases)
    plt.plot(b_name.date,b_name.total_cases)
    
    # labelling
    plt.title(f"Covid chart {name1} and {name2}")
    plt.xlabel("Date")
    plt.ylabel("Number")
    plt.legend([name1,name2])
    # Display
    plt.show()
    
    
name1 = input('Enter first country: ')
name2 = input('Enter second country: ')

total_compare(name1,name2)
# Out:
# Enter first country: Pakistan
# Enter second country: France

# %%
# Ploting the graph


plt.figure(figsize=(20,10))

# Getting the data to plot
plt.plot(nepal.date,nepal.total_cases)
plt.plot(nepal.date,nepal.new_cases)


# labelling
plt.title("Covid Nepal")
plt.xlabel("Date")
plt.ylabel("Number")
plt.legend(['Total','New'])

# Display
plt.show()

# %%
# Ploting the graph


plt.figure(figsize=(20,10))

# Getting the data to plot
plt.plot(aus.date,aus.total_cases)
plt.plot(aus.date,aus.new_cases)


# labelling
plt.title("Covid Australia")
plt.xlabel("Date")
plt.ylabel("Number")
plt.legend(['Total','New'])

# Display
plt.show()

# %%
# Ploting the graph


plt.figure(figsize=(20,10))

# Getting the data to plot
plt.plot(aus.date,aus.total_cases)
plt.plot(nepal.date,nepal.total_cases)

# labelling
plt.title("Total COIVD cases")
plt.xlabel("Date")
plt.ylabel("Number")
plt.legend(['Aus','Nep'])

# Display
plt.show()

# %%
# Ploting the graph


plt.figure(figsize=(20,10))
plt.grid(color='#95a5a6', linestyle='--', linewidth=2, axis='y', alpha=0.7)

# Getting the data to plot
plt.plot(aus.date,aus.new_cases)
plt.plot(nepal.date,nepal.new_cases)
plt.plot(nepal.date,ind.new_cases)


# labelling
plt.title("New COIVD cases")
plt.xlabel("Date")
plt.ylabel("Number")
plt.legend(['Aus','Nep','India'])

# Display
plt.show()

# %%
# data to plot
n_groups = 4
means_frank = (90, 55, 40, 65)
means_guido = (85, 62, 54, 20)

# create plot
fig, ax = plt.subplots()
index = np.arange(n_groups)
bar_width = 0.35
opacity = 0.8

# print(index)

rects1 = plt.bar(index, means_frank, bar_width,
alpha=opacity,
color='b',
label='Frank')

rects2 = plt.bar(index + bar_width, means_guido, bar_width,
alpha=opacity,
color='g',
label='Guido')

plt.xlabel('Person')
plt.ylabel('Scores')
plt.title('Scores by person')
plt.xticks(index + bar_width, ('A', 'B', 'C', 'D'))
plt.legend()

plt.tight_layout()
plt.show()
# Out:
# [0 1 2 3]
